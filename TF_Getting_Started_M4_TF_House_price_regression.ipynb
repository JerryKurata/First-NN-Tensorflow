# %% [markdown]
# <a href="https://colab.research.google.com/github/JerryKurata/First-NN-Tensorflow/blob/master/TF_Getting_Started_M4_TF_House_price_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tensor Flow House Price Prediction
#
# This is a simple Tensorflow based notebook that applies the steps of the machine learning workflow to create, train, and test a model that will predict house prices.
#
# The notebook:
#
# *  Uses the steps of the machine workflow discussed in the course
# *  Illustrates how TensorFlow makes it easier to implement a machine learning solution
# *  Describes what is happening in various processing steps

# %% [markdown]
# ## Load correct version of TensorFlow
# Before we use TensorFlow we must load the correct version.  We want version 2.x.  To do this we execute the colab commands below.  Note that these commands **ONLY WORK IN COLAB.**

# %%
# Install TensorFlow using Colab's tensorflow_version command
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# ## Import Libraries
#
# We import TensorFlow, Numpy, and matplotlib libraries.
#
# Numpy is a powerful N-dimensional array library that
# allows us to easily create and manipulate arrays of data, and more!
#
# Numpy also allows us to convert TensorFlow's native data structures,
# to python native data types.
#
# matplotlib is a graphics plot library

# %%
# Import libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Check TensorFlow version
print("TensorFlow version:", tf.__version__)

# In colab we can get GPU acceleration if we install tensorflow-gpu 
#   and turn on GPU in Notebook settings
print("GPU is available:", tf.test.is_gpu_available())
# Out:
# TensorFlow version: 2.0.0
# GPU is available: True

# %% [markdown]
# ## Problem Statement
#
# Using example data, develop a model that predict house prices based on the size of a house.

# %% [markdown]
# ## Get Data
#
# In this example we will be using a truncated version of the Ames dataset that only contains information on homes sold in May 2010.
#
# ### About the Ames dataset.
#
# The Ames dataset is a widely avalable dataset that has become one of the standard datasets used when
# predicting home prices based on features of the home. It is based on the great work of Dean De Cock.  His rational
# and insight into this dataset can be found at http://jse.amstat.org/v19n3/decock.pdf.
#
#
# ### Getting the truncated dataset we use
# This data set can be found with the exercise files for this course.  The filename is **AmesHousing-05-2010.csv** .
#
# Before you run the code below, ensure you have downloaded the file to your computer.
#
# And when prompted, browse to the file's location on your computer and upload the file.
#
# *Warning: The file upload function will only show the file selection dialog for 30 seconds.  After that time it will close and cause an error because a file was not specified.  This timeout prevents the file dialog from blocking events in colab.  If you experience this timeout select the dataset file sooner.  It may help to move the dataset file to an easier to specify location such as your desktop.*

# %%
# You need to upload the file, AmesHousing-05-2001.csv provided with this course
from google.colab import files

# only load the single file
uploaded = files.upload()
# csv_filename contains the name of the first, and only file uploaded
csv_housefile = next(iter(uploaded.keys()))

print('User uploaded file "{name}" with length {length} bytes'.format(
      name=csv_housefile, length=len(uploaded[csv_housefile])))
# Out:
#      <input type="file" id="files-6414eda2-5365-47b3-b664-0a398e3ae287" name="files[]" multiple disabled />
#      <output id="result-6414eda2-5365-47b3-b664-0a398e3ae287">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AmesHousing-05-2010.csv to AmesHousing-05-2010 (6).csv
# User uploaded file "AmesHousing-05-2010.csv" with length 20140 bytes

# %% [markdown]
# ### Load the data into a pandas dataframe
#
# Pandas let's use easily review and manipulate the data.  If you are new to pandas, see https://pandas.pydata.org/ and the pandas 10 minute intro  http://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html to understand how pandas, and pandas dataframes makes working with tabular data in Python easy.

# %%
import io
import pandas as pd

# load the housing data into a pandas dataframe for easy viewing and manipulation
df_housing = pd.read_csv(csv_housefile)

# %% [markdown]
# ### Visualize the House Price data
#
# We use panda's  head method to look at the first few rows of data.  This will give use an understanding of the data we are working with.

# %%
# Visualize the dataset
 
# turn on option to display all columns, otherwise some columns may be hidden
pd.set_option('display.max_columns', None)  
# print the column names and first 5 rows of data
df_housing.head(5)
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1     13  527166040           60        RL          63.0      8402   Pave
# 2     38  528112020           20        RL          98.0     11478   Pave
# 3     56  528240070           60        RL           NaN      7851   Pave
# 4     59  528292020           60        RL           NaN      9505   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 2   NaN       Reg          Lvl    AllPub     Inside        Gtl      NridgHt
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      Gilbert
# 4   NaN       IR1          Lvl    AllPub    CulDSac        Gtl      Gilbert
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm      1Fam      1Story             6             5
# 1        Norm        Norm      1Fam      2Story             6             5
# 2        Norm        Norm      1Fam      1Story             8             5
# 3        Norm        Norm      1Fam      2Story             6             5
# 4        Norm        Norm      1Fam      2Story             7             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1960            1960        Hip   CompShg      BrkFace      Plywood
# 1        1998            1998      Gable   CompShg      VinylSd      VinylSd
# 2        2007            2008      Gable   CompShg      VinylSd      VinylSd
# 3        2002            2002      Gable   CompShg      VinylSd      VinylSd
# 4        2001            2001      Gable   CompShg      VinylSd      VinylSd
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0        Stone         112.0         TA         TA     CBlock        TA
# 1         None           0.0         TA         TA      PConc        Gd
# 2        Stone         200.0         Gd         TA      PConc        Ex
# 3          NaN           NaN         Gd         TA      PConc        Gd
# 4      BrkFace         180.0         Gd         TA      PConc        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        Gd            Gd            BLQ           639            Unf
# 1        TA            No            Unf             0            Unf
# 2        TA            No            GLQ          1218            Unf
# 3        TA            No            GLQ           625            Unf
# 4        TA            No            Unf             0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0             0          441           1080    GasA         Fa           Y
# 1             0          789            789    GasA         Gd           Y
# 2             0          486           1704    GasA         Ex           Y
# 3             0          235            860    GasA         Ex           Y
# 4             0          884            884    GasA         Ex           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr        1656           0                0         1656
# 1      SBrkr         789         676                0         1465
# 2      SBrkr        1704           0                0         1704
# 3      SBrkr         860        1100                0         1960
# 4      SBrkr         884        1151                0         2035
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0               1               0          1          0              3
# 1               0               0          2          1              3
# 2               1               0          2          0              3
# 3               1               0          2          1              4
# 4               0               0          2          1              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           TA              7        Typ           2
# 1              1           TA              7        Typ           1
# 2              1           Gd              7        Typ           1
# 3              1           Gd              8        Typ           2
# 4              1           Gd              8        Typ           1
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0           Gd      Attchd         1960.0           Fin            2
# 1           Gd      Attchd         1998.0           Fin            2
# 2           Gd      Attchd         2008.0           RFn            3
# 3           TA     BuiltIn         2002.0           Fin            2
# 4           Gd     BuiltIn         2001.0           Fin            2
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0          528          TA          TA           P           210
# 1          393          TA          TA           Y             0
# 2          772          TA          TA           Y             0
# 3          440          TA          TA           Y           288
# 4          434          TA          TA           Y           144
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area  \
# 0             62               0           0             0          0
# 1             75               0           0             0          0
# 2             50               0           0             0          0
# 3             48               0           0             0          0
# 4             48               0           0             0          0
#
#    Pool QC Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  \
# 0      NaN   NaN          NaN         0        5     2010       WD
# 1      NaN   NaN          NaN         0        5     2010       WD
# 2      NaN   NaN          NaN         0        5     2010       WD
# 3      NaN   NaN          NaN         0        5     2010       WD
# 4      NaN   NaN          NaN         0        5     2010       WD
#
#   Sale Condition  SalePrice
# 0         Normal     215000
# 1         Normal     180400
# 2         Normal     306000
# 3         Normal     216500
# 4         Normal     222500

# %% [markdown]
# Lots of feature columns.  From documentation of previous work with this data I believe that we can account for most of the difference in price (SalePrice) based on the size of the house.
#
# Looking through the columns we see the following features contains 'SF': BsmtFin SF 1, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF,  1st Flr SF, 2nd Flr SF, Low Qual Fin SF.
#
# A little more checking the data and we see in the data that there are summary columns for the bsement square footage and the above basement square footage.  Specific the feature columns Total Bsmt SF and Gr Liv Area sum the space as follows:
#
#
#
# >  Total Bsmt SF = BsmtFin SF 1 +  BsmtFin SF 2 + Bsmt Unf SF
#
# > Gr Liv Area =  1st Flr SF +  2nd Flr SF
#
# But, there is no feature for the total space in the house which is the sum of Basement and Upper floors or (Total Bsmt SF + Gr Liv Area ).  So let's add a new feature column containing this value called 'Total SF' to the dataset.
#
# But, before we proceed, let's see if the feature columns we are dependent upon contain missing values that will effect our results.  If so, we can remove the rows with missing columns or determine a way of imputing (updating the values) the missing columns.

# %%
 df_housing[['Total Bsmt SF', 'Gr Liv Area']].isnull().values.any()
# Out:
# False

# %% [markdown]
# No missing values, so additional work is required.  So we can add the new column Total SF.

# %%
# Add new feature column Total SF = Total Bsmt SF + Gr Liv Area
df_housing['Total SF'] = df_housing['Total Bsmt SF'] + df_housing['Gr Liv Area']

# %% [markdown]
# And we can check the numbers add and see associated sale price

# %%
# see the  bsmt and living area, total sf, and price columns
print(df_housing[['Total Bsmt SF', 'Gr Liv Area', 'Total SF', 'SalePrice']].head(5) )
# Out:
#    Total Bsmt SF  Gr Liv Area  Total SF  SalePrice
# 0           1080         1656      2736     215000
# 1            789         1465      2254     180400
# 2           1704         1704      3408     306000
# 3            860         1960      2820     216500
# 4            884         2035      2919     222500

# %% [markdown]
# ### Visualize the data.
#
# We visualize the data to give us some idea of the relationships between the various features.  To do that we create a  function to plot the data.

# %%
# This function visualizes our data and optionally a learned line
def visualize_data(x_vals, y_vals,
                   addn_x_vals=None, addn_y_vals=None, add_addn_reg_line=False):
  
  f, ax = plt.subplots(figsize=(8,8))
  plt.plot(x_vals, y_vals, 'ro')   # red dot for each data point
  # Optional plot another set of data points in a different color and symbol
  if (addn_x_vals is not None):
    plt.plot(addn_x_vals, addn_y_vals, 'g^') # green triangles for addition data points
    # Optionally, draw points of x,y pairs as green triangles.
    if (add_addn_reg_line):
      x_min_index = addn_x_vals.argmin()
      x_max_index = addn_x_vals.argmax()
      print(x_min_index,[addn_x_vals[x_min_index],addn_y_vals[x_min_index]] ) 
      print(x_max_index,[addn_x_vals[x_max_index],addn_y_vals[x_max_index]] ) 
      plt.plot([addn_x_vals[x_min_index],addn_y_vals[x_min_index]], 
               [addn_x_vals[x_max_index],addn_y_vals[x_max_index]], 
               'b-')  # draw a blue regression line
    
  plt.tick_params(axis='both', which='major', labelsize=14)
  
  plt.show()  # now plot the line showing the data and optionally the line

# %% [markdown]
# ### Visualizing Total SF and Price
#
# Using the visualize data function we can see the relationship between Total Square Feet (Total SF) and Price.

# %%
# Plot Price vs. Total SF
visualize_data(df_housing['Total SF'], df_housing['SalePrice'])

# %% [markdown]
# ### What does the visualization tell us?
#
# There seems to definitely be a **linear** relationship between the size of the house (as shown in Total SF) and Price.
#
# This suggests that we should perform Linear Regression. Where the relationship in the data is:
#  y = f(x).  Or in our case, Price = f(Total SF)
#
# With respect to defining the function f(x), we can sum the difference between traditional programming and Machine Learning as:
#
# * In tradition programming **we define what f(x)** is through structures such as equations or conditional statements
#
# * In Machine Learning, our model **learns from the data** what the function f(x) is.

# %% [markdown]
# ### Additional Pre-processing
#
# Before we can use our data, we want to do 2 tasks.
#
# 1.   Scale the data.  If values are on very different scales it will be difficult for the model to determine the relationships between features.  With our data, Square Footage(SF) ranges from 800-4200, and Prices range from 80,000 to 400,0000.  This means there is a nearly 100 times different in scale.  When we normalize we will reduce both qualtities to the same scale while preserving the differences between prices and sizes of homes.  This will help our model learn the relationship between price and size.
#
# 2.   Once we have this new dataset we want to split the dataset into 2 dataset.  One dataset will be used for training, and other dataset will used for testing.  **We never used testing data for training or training data for testing.**

# %%
#  Create new dataset with only Total_SF and SalePrice columns
#df_TotalSF_SalePrice = df_housing[['Total SF', 'SalePrice']]
#print(df_TotalSF_SalePrice.head(5))

# save for additional usage
#df_TotalSF_SalePrice.to_csv('df_totalsf_saleprice.csv')

# download the file to the user's system
#from google.colab import files
#files.download('df_totalsf_saleprice.csv')

# %%
# Scale data so SF and Sale Price are on similar scales with values 
#  from 0.0 to 1.0

from sklearn.preprocessing import MinMaxScaler

sf_scaler = MinMaxScaler()
sf_scaled = sf_scaler.fit_transform(df_housing['Total SF'].values.reshape(-1,1).astype(np.float64))
    
price_scaler = MinMaxScaler()
price_scaled = price_scaler.fit_transform(df_housing['SalePrice'].values.reshape(-1,1).astype(np.float64))

# %%
# Split the dataset into training dataset - 70%, Testing dateset - 30%
# we do this using the sklearn train_test_split method
from sklearn.model_selection import train_test_split

sf_train_scaled, sf_test_scaled, price_train_scaled, price_test_scaled = train_test_split(sf_scaled, 
                                                    price_scaled, 
                                                    test_size=0.3, random_state=42)

# %% [markdown]
# ## Create Model
#
# Here we create a model to learn from our data.  Our data looks linearly related, so can use a straight line
# to fit our data.  So we are going to create a model that is based on the equation of a straight line.
#
# And from our training data we will learn line once we can define this line's parameters we can use it's equation to predict the value of any future data.
#
# We use Tensorflow's Keras library to make the process easy.
#
# We create a sequential model with where the output of one layer becomes the input of the next layer.
#
# This model will is a simple Neural Network that implements y = wx + bias, where **w is a weight** and **bias is an offset**.
#
# *You may recognize from Geometry that y = wx + bias is the equation of straight line, where w is the slope and bias is the offset.  (See https://en.wikipedia.org/wiki/Line_(geometry) for a description.)*
#
# Therefore the goal is to use our data to train the model and learn the best values for w and bias.

# %% [markdown]
# ### Our Model
#
# We create our linear model using TensorFlow's Keras library.   Using Keras makes it easy for us to create, train, and evaluate our model.

# %%
# Create model using the TensorFlow Keras library
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=1, activation='linear', input_shape=[1]))

# %% [markdown]
# ### Compile the model
#
# The model is now defined, but is not trained, or even ready to be trained.
#
# We will train the model by passing training data throught it and adjusting the weight and bias to reduce loss (error).  To perform these tasks we need a method for
# *  measuring loss and
# *  optimizing the values of the weight and bias to minimize this loss.
#
# There are many ways of measuring loss and optimizing the values.  We are going to use **Mean-Squared Error** ('mean_squared_error') to measure loss, and the process of **Root-Mean-Square Propgation** ('rmsprop') to find the optimal weight and bias to minimize the loss.
#
# We set these parameters for the model with the **compile** statement.

# %%
# Compile model
optimizer = tf.keras.optimizers.RMSprop(0.1)
model.compile(loss='mean_squared_error', optimizer=optimizer)
#model.compile(loss='mean_squared_error', optimizer='rmsprop')

# %% [markdown]
# ## Train the Model
#
# Once the model has been defined and training methodology compiled we can train the model.  We do this with our training data.  We pass the training data through the model multiple times.  And on each pass the loss function we defined in the model compile will be used to calculate loss.  And the optimizer will be used to make adjustments to the weights and bias (just called weights from hear on) to minimize this error.
#
# We will repeat this process of calculating the loss with the current weights, measuring loss, and updating the weights to minimize loss for the specified number of **epochs**.  *We should see the loss decrease over time *
#
#
# We can set *verbose* flag to tell Keras how much information to show during the training process, 0 is none, 1 and 2 show more in-progress information.

# %%
# Train model using data
initial_epochs = 8
train_hist = model.fit(sf_train_scaled, price_train_scaled, epochs=initial_epochs, verbose=1)

# Is 10 epochs enough??? Maybe/Maybe not
# Out:
# Train on 41 samples
# Epoch 1/8
# 41/41 [==============================] - 1s 18ms/sample - loss: 0.5687
# Epoch 2/8
# 41/41 [==============================] - 0s 338us/sample - loss: 0.1179
# Epoch 3/8
# 41/41 [==============================] - 0s 270us/sample - loss: 0.0783
# Epoch 4/8
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0759
# Epoch 5/8
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0695
# Epoch 6/8
# 41/41 [==============================] - 0s 251us/sample - loss: 0.0580
# Epoch 7/8
# 41/41 [==============================] - 0s 276us/sample - loss: 0.0526
# Epoch 8/8
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0493

# %% [markdown]
# ### Visually Confirm Model Training
#
# Our model learned the best weight and bias for our training data.  Let's see if a line drawn with these learned weight and bias looks reasonable.

# %%
#  predict the price with our trained model
price_predicted_scaled =  model.predict(sf_train_scaled)
visualize_data(sf_scaler.inverse_transform(sf_train_scaled), price_scaler.inverse_transform(price_train_scaled),
               sf_scaler.inverse_transform(sf_train_scaled), price_scaler.inverse_transform(price_predicted_scaled),
               add_addn_reg_line=False)
               
# If line looks bad, what do we do?

# %% [markdown]
# ### Evaluate Training
#
#
# Does not looks too good !!!
#
# What can we do?
#
# Should we change model architecture?  Does linear look incorrect?
#
# > NO
#
#
# What does loss look like?

# %%
def plot_loss(hist):
  # plot the loss
  plt.title('Loss History')
  plt.plot(hist.history['loss'])
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.show()

print(type(train_hist))
plot_loss(train_hist)
# Out:
# <class 'tensorflow.python.keras.callbacks.History'>

# %% [markdown]
# > LOSS STILL LOOK HIGH.  BUT IS DECREASING.
#
#
#
# Perhaps we have not converged.  What can we do????
#
# Train with more data?
#
# > NO.  WE HAVE ALL THE DATA
#
# Train for more epochs and check loss to ensure values have converged?
#  > YES!!!

# %% [markdown]
# ### Training more epochs
#
# The model is partially trained but the results are not great.  Let's go back and train the model some more.
#
# The question is how much more?
#
# We want to ensure the model is converged to a range of loss values.   So what we will see in the training output is the loss value starts to stay in a specific range .   It may go up or down a little, but there should be a stable range.

# %%
# Train model using data.  This time, train for additional epochs
# Also capture the changed over time in the history variable, train_hist so we 
#   can see if loss is converging
addn_epochs = 1000
train_hist_addn =model.fit(sf_train_scaled, price_train_scaled,  
                     epochs=addn_epochs, verbose=1)
# Out:
# Train on 41 samples
# Epoch 1/1000
# 41/41 [==============================] - 0s 437us/sample - loss: 0.0502
# Epoch 2/1000
# 41/41 [==============================] - 0s 279us/sample - loss: 0.0376
# Epoch 3/1000
# 41/41 [==============================] - 0s 239us/sample - loss: 0.0410
# Epoch 4/1000
# 41/41 [==============================] - 0s 309us/sample - loss: 0.0336
# Epoch 5/1000
# 41/41 [==============================] - 0s 287us/sample - loss: 0.0385
# Epoch 6/1000
# 41/41 [==============================] - 0s 287us/sample - loss: 0.0254
# Epoch 7/1000
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0204
# Epoch 8/1000
# 41/41 [==============================] - 0s 253us/sample - loss: 0.0191
# Epoch 9/1000
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0208
# Epoch 10/1000
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0419
# Epoch 11/1000
# 41/41 [==============================] - 0s 345us/sample - loss: 0.0324
# Epoch 12/1000
# 41/41 [==============================] - 0s 270us/sample - loss: 0.0147
# Epoch 13/1000
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0153
# Epoch 14/1000
# 41/41 [==============================] - 0s 352us/sample - loss: 0.0145
# Epoch 15/1000
# 41/41 [==============================] - 0s 298us/sample - loss: 0.0144
# Epoch 16/1000
# 41/41 [==============================] - 0s 245us/sample - loss: 0.0184
# Epoch 17/1000
# 41/41 [==============================] - 0s 423us/sample - loss: 0.0147
# Epoch 18/1000
# 41/41 [==============================] - 0s 318us/sample - loss: 0.0148
# Epoch 19/1000
# 41/41 [==============================] - 0s 252us/sample - loss: 0.0165
# Epoch 20/1000
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0205
# Epoch 21/1000
# 41/41 [==============================] - 0s 274us/sample - loss: 0.0132
# Epoch 22/1000
# 41/41 [==============================] - 0s 297us/sample - loss: 0.0274
# Epoch 23/1000
# 41/41 [==============================] - 0s 300us/sample - loss: 0.0275
# Epoch 24/1000
# 41/41 [==============================] - 0s 312us/sample - loss: 0.0182
# Epoch 25/1000
# 41/41 [==============================] - 0s 429us/sample - loss: 0.0132
# Epoch 26/1000
# 41/41 [==============================] - 0s 379us/sample - loss: 0.0246
# Epoch 27/1000
# 41/41 [==============================] - 0s 351us/sample - loss: 0.0469
# Epoch 28/1000
# 41/41 [==============================] - 0s 267us/sample - loss: 0.0189
# Epoch 29/1000
# 41/41 [==============================] - 0s 264us/sample - loss: 0.0144
# Epoch 30/1000
# 41/41 [==============================] - 0s 241us/sample - loss: 0.0132
# Epoch 31/1000
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0182
# Epoch 32/1000
# 41/41 [==============================] - 0s 342us/sample - loss: 0.0165
# Epoch 33/1000
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0171
# Epoch 34/1000
# 41/41 [==============================] - 0s 629us/sample - loss: 0.0185
# Epoch 35/1000
# 41/41 [==============================] - 0s 410us/sample - loss: 0.0148
# Epoch 36/1000
# 41/41 [==============================] - 0s 304us/sample - loss: 0.0173
# Epoch 37/1000
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0164
# Epoch 38/1000
# 41/41 [==============================] - 0s 352us/sample - loss: 0.0242
# Epoch 39/1000
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0299
# Epoch 40/1000
# 41/41 [==============================] - 0s 240us/sample - loss: 0.0253
# Epoch 41/1000
# 41/41 [==============================] - 0s 351us/sample - loss: 0.0180
# Epoch 42/1000
# 41/41 [==============================] - 0s 406us/sample - loss: 0.0267
# Epoch 43/1000
# 41/41 [==============================] - 0s 264us/sample - loss: 0.0310
# Epoch 44/1000
# 41/41 [==============================] - 0s 310us/sample - loss: 0.0148
# Epoch 45/1000
# 41/41 [==============================] - 0s 281us/sample - loss: 0.0163
# Epoch 46/1000
# 41/41 [==============================] - 0s 232us/sample - loss: 0.0132
# Epoch 47/1000
# 41/41 [==============================] - 0s 370us/sample - loss: 0.0239
# Epoch 48/1000
# 41/41 [==============================] - 0s 323us/sample - loss: 0.0205
# Epoch 49/1000
# 41/41 [==============================] - 0s 270us/sample - loss: 0.0138
# Epoch 50/1000
# 41/41 [==============================] - 0s 214us/sample - loss: 0.0130
# Epoch 51/1000
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0159
# Epoch 52/1000
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0164
# Epoch 53/1000
# 41/41 [==============================] - 0s 336us/sample - loss: 0.0202
# Epoch 54/1000
# 41/41 [==============================] - 0s 368us/sample - loss: 0.0321
# Epoch 55/1000
# 41/41 [==============================] - 0s 285us/sample - loss: 0.0137
# Epoch 56/1000
# 41/41 [==============================] - 0s 244us/sample - loss: 0.0139
# Epoch 57/1000
# 41/41 [==============================] - 0s 344us/sample - loss: 0.0146
# Epoch 58/1000
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0178
# Epoch 59/1000
# 41/41 [==============================] - 0s 375us/sample - loss: 0.0384
# Epoch 60/1000
# 41/41 [==============================] - 0s 431us/sample - loss: 0.0247
# Epoch 61/1000
# 41/41 [==============================] - 0s 264us/sample - loss: 0.0141
# Epoch 62/1000
# 41/41 [==============================] - 0s 374us/sample - loss: 0.0261
# Epoch 63/1000
# 41/41 [==============================] - 0s 425us/sample - loss: 0.0131
# Epoch 64/1000
# 41/41 [==============================] - 0s 252us/sample - loss: 0.0172
# Epoch 65/1000
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0135
# Epoch 66/1000
# 41/41 [==============================] - 0s 261us/sample - loss: 0.0149
# Epoch 67/1000
# 41/41 [==============================] - 0s 312us/sample - loss: 0.0162
# Epoch 68/1000
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0243
# Epoch 69/1000
# 41/41 [==============================] - 0s 423us/sample - loss: 0.0213
# Epoch 70/1000
# 41/41 [==============================] - 0s 322us/sample - loss: 0.0146
# Epoch 71/1000
# 41/41 [==============================] - 0s 292us/sample - loss: 0.0140
# Epoch 72/1000
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0353
# Epoch 73/1000
# 41/41 [==============================] - 0s 268us/sample - loss: 0.0187
# Epoch 74/1000
# 41/41 [==============================] - 0s 329us/sample - loss: 0.0193
# Epoch 75/1000
# 41/41 [==============================] - 0s 262us/sample - loss: 0.0131
# Epoch 76/1000
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0151
# Epoch 77/1000
# 41/41 [==============================] - 0s 267us/sample - loss: 0.0130
# Epoch 78/1000
# 41/41 [==============================] - 0s 222us/sample - loss: 0.0258
# Epoch 79/1000
# 41/41 [==============================] - 0s 300us/sample - loss: 0.0315
# Epoch 80/1000
# 41/41 [==============================] - 0s 393us/sample - loss: 0.0133
# Epoch 81/1000
# 41/41 [==============================] - 0s 360us/sample - loss: 0.0285
# Epoch 82/1000
# 41/41 [==============================] - 0s 281us/sample - loss: 0.0210
# Epoch 83/1000
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0294
# Epoch 84/1000
# 41/41 [==============================] - 0s 344us/sample - loss: 0.0277
# Epoch 85/1000
# 41/41 [==============================] - 0s 309us/sample - loss: 0.0151
# Epoch 86/1000
# 41/41 [==============================] - 0s 410us/sample - loss: 0.0152
# Epoch 87/1000
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0166
# Epoch 88/1000
# 41/41 [==============================] - 0s 309us/sample - loss: 0.0186
# Epoch 89/1000
# 41/41 [==============================] - 0s 315us/sample - loss: 0.0248
# Epoch 90/1000
# 41/41 [==============================] - 0s 319us/sample - loss: 0.0168
# Epoch 91/1000
# 41/41 [==============================] - 0s 375us/sample - loss: 0.0155
# Epoch 92/1000
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0182
# Epoch 93/1000
# 41/41 [==============================] - 0s 357us/sample - loss: 0.0193
# Epoch 94/1000
# 41/41 [==============================] - 0s 334us/sample - loss: 0.0167
# Epoch 95/1000
# 41/41 [==============================] - 0s 343us/sample - loss: 0.0147
# Epoch 96/1000
# 41/41 [==============================] - 0s 381us/sample - loss: 0.0131
# Epoch 97/1000
# 41/41 [==============================] - 0s 346us/sample - loss: 0.0152
# Epoch 98/1000
# 41/41 [==============================] - 0s 648us/sample - loss: 0.0366
# Epoch 99/1000
# 41/41 [==============================] - 0s 377us/sample - loss: 0.0246
# Epoch 100/1000
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0131
# Epoch 101/1000
# 41/41 [==============================] - 0s 290us/sample - loss: 0.0167
# Epoch 102/1000
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0171
# Epoch 103/1000
# 41/41 [==============================] - 0s 247us/sample - loss: 0.0191
# Epoch 104/1000
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0216
# Epoch 105/1000
# 41/41 [==============================] - 0s 281us/sample - loss: 0.0135
# Epoch 106/1000
# 41/41 [==============================] - 0s 245us/sample - loss: 0.0140
# Epoch 107/1000
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0133
# Epoch 108/1000
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0139
# Epoch 109/1000
# 41/41 [==============================] - 0s 236us/sample - loss: 0.0126
# Epoch 110/1000
# 41/41 [==============================] - 0s 289us/sample - loss: 0.0405
# Epoch 111/1000
# 41/41 [==============================] - 0s 270us/sample - loss: 0.0272
# Epoch 112/1000
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0166
# Epoch 113/1000
# 41/41 [==============================] - 0s 309us/sample - loss: 0.0135
# Epoch 114/1000
# 41/41 [==============================] - 0s 331us/sample - loss: 0.0209
# Epoch 115/1000
# 41/41 [==============================] - 0s 309us/sample - loss: 0.0224
# Epoch 116/1000
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0184
# Epoch 117/1000
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0130
# Epoch 118/1000
# 41/41 [==============================] - 0s 386us/sample - loss: 0.0131
# Epoch 119/1000
# 41/41 [==============================] - 0s 342us/sample - loss: 0.0162
# Epoch 120/1000
# 41/41 [==============================] - 0s 288us/sample - loss: 0.0155
# Epoch 121/1000
# 41/41 [==============================] - 0s 285us/sample - loss: 0.0250
# Epoch 122/1000
# 41/41 [==============================] - 0s 230us/sample - loss: 0.0356
# Epoch 123/1000
# 41/41 [==============================] - 0s 301us/sample - loss: 0.0134
# Epoch 124/1000
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0191
# Epoch 125/1000
# 41/41 [==============================] - 0s 283us/sample - loss: 0.0224
# Epoch 126/1000
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0323
# Epoch 127/1000
# 41/41 [==============================] - 0s 292us/sample - loss: 0.0131
# Epoch 128/1000
# 41/41 [==============================] - 0s 300us/sample - loss: 0.0192
# Epoch 129/1000
# 41/41 [==============================] - 0s 330us/sample - loss: 0.0146
# Epoch 130/1000
# 41/41 [==============================] - 0s 412us/sample - loss: 0.0178
# Epoch 131/1000
# 41/41 [==============================] - 0s 363us/sample - loss: 0.0312
# Epoch 132/1000
# 41/41 [==============================] - 0s 311us/sample - loss: 0.0277
# Epoch 133/1000
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0136
# Epoch 134/1000
# 41/41 [==============================] - 0s 348us/sample - loss: 0.0234
# Epoch 135/1000
# 41/41 [==============================] - 0s 400us/sample - loss: 0.0132
# Epoch 136/1000
# 41/41 [==============================] - 0s 345us/sample - loss: 0.0162
# Epoch 137/1000
# 41/41 [==============================] - 0s 356us/sample - loss: 0.0320
# Epoch 138/1000
# 41/41 [==============================] - 0s 317us/sample - loss: 0.0255
# Epoch 139/1000
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0133
# Epoch 140/1000
# 41/41 [==============================] - 0s 308us/sample - loss: 0.0169
# Epoch 141/1000
# 41/41 [==============================] - 0s 256us/sample - loss: 0.0134
# Epoch 142/1000
# 41/41 [==============================] - 0s 400us/sample - loss: 0.0211
# Epoch 143/1000
# 41/41 [==============================] - 0s 337us/sample - loss: 0.0135
# Epoch 144/1000
# 41/41 [==============================] - 0s 349us/sample - loss: 0.0134
# Epoch 145/1000
# 41/41 [==============================] - 0s 253us/sample - loss: 0.0133
# Epoch 146/1000
# 41/41 [==============================] - 0s 422us/sample - loss: 0.0136
# Epoch 147/1000
# 41/41 [==============================] - 0s 261us/sample - loss: 0.0163
# Epoch 148/1000
# 41/41 [==============================] - 0s 319us/sample - loss: 0.0175
# Epoch 149/1000
# 41/41 [==============================] - 0s 230us/sample - loss: 0.0274
# Epoch 150/1000
# 41/41 [==============================] - 0s 344us/sample - loss: 0.0401
# Epoch 151/1000
# 41/41 [==============================] - 0s 226us/sample - loss: 0.0140
# Epoch 152/1000
# 41/41 [==============================] - 0s 264us/sample - loss: 0.0134
# Epoch 153/1000
# 41/41 [==============================] - 0s 253us/sample - loss: 0.0248
# Epoch 154/1000
# 41/41 [==============================] - 0s 386us/sample - loss: 0.0272
# Epoch 155/1000
# 41/41 [==============================] - 0s 356us/sample - loss: 0.0163
# Epoch 156/1000
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0197
# Epoch 157/1000
# 41/41 [==============================] - 0s 281us/sample - loss: 0.0184
# Epoch 158/1000
# 41/41 [==============================] - 0s 322us/sample - loss: 0.0143
# Epoch 159/1000
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0236
# Epoch 160/1000
# 41/41 [==============================] - 0s 336us/sample - loss: 0.0304
# Epoch 161/1000
# 41/41 [==============================] - 0s 384us/sample - loss: 0.0173
# Epoch 162/1000
# 41/41 [==============================] - 0s 332us/sample - loss: 0.0143
# Epoch 163/1000
# 41/41 [==============================] - 0s 304us/sample - loss: 0.0194
# Epoch 164/1000
# 41/41 [==============================] - 0s 239us/sample - loss: 0.0216
# Epoch 165/1000
# 41/41 [==============================] - 0s 414us/sample - loss: 0.0278
# Epoch 166/1000
# 41/41 [==============================] - 0s 400us/sample - loss: 0.0145
# Epoch 167/1000
# 41/41 [==============================] - 0s 304us/sample - loss: 0.0180
# Epoch 168/1000
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0192
# Epoch 169/1000
# 41/41 [==============================] - 0s 384us/sample - loss: 0.0131
# Epoch 170/1000
# 41/41 [==============================] - 0s 377us/sample - loss: 0.0131
# Epoch 171/1000
# 41/41 [==============================] - 0s 255us/sample - loss: 0.0194
# Epoch 172/1000
# 41/41 [==============================] - 0s 318us/sample - loss: 0.0166
# Epoch 173/1000
# 41/41 [==============================] - 0s 317us/sample - loss: 0.0364
# Epoch 174/1000
# 41/41 [==============================] - 0s 415us/sample - loss: 0.0176
# Epoch 175/1000
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0133
# Epoch 176/1000
# 41/41 [==============================] - 0s 396us/sample - loss: 0.0247
# Epoch 177/1000
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0263
# Epoch 178/1000
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0143
# Epoch 179/1000
# 41/41 [==============================] - 0s 334us/sample - loss: 0.0270
# Epoch 180/1000
# 41/41 [==============================] - 0s 345us/sample - loss: 0.0142
# Epoch 181/1000
# 41/41 [==============================] - 0s 366us/sample - loss: 0.0158
# Epoch 182/1000
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0169
# Epoch 183/1000
# 41/41 [==============================] - 0s 363us/sample - loss: 0.0136
# Epoch 184/1000
# 41/41 [==============================] - 0s 293us/sample - loss: 0.0130
# Epoch 185/1000
# 41/41 [==============================] - 0s 474us/sample - loss: 0.0128
# Epoch 186/1000
# 41/41 [==============================] - 0s 413us/sample - loss: 0.0341
# Epoch 187/1000
# 41/41 [==============================] - 0s 395us/sample - loss: 0.0151
# Epoch 188/1000
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0456
# Epoch 189/1000
# 41/41 [==============================] - 0s 319us/sample - loss: 0.0178
# Epoch 190/1000
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0134
# Epoch 191/1000
# 41/41 [==============================] - 0s 267us/sample - loss: 0.0226
# Epoch 192/1000
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0134
# Epoch 193/1000
# 41/41 [==============================] - 0s 345us/sample - loss: 0.0145
# Epoch 194/1000
# 41/41 [==============================] - 0s 242us/sample - loss: 0.0142
# Epoch 195/1000
# 41/41 [==============================] - 0s 244us/sample - loss: 0.0292
# Epoch 196/1000
# 41/41 [==============================] - 0s 273us/sample - loss: 0.0335
# Epoch 197/1000
# 41/41 [==============================] - 0s 377us/sample - loss: 0.0133
# Epoch 198/1000
# 41/41 [==============================] - 0s 341us/sample - loss: 0.0227
# Epoch 199/1000
# 41/41 [==============================] - 0s 369us/sample - loss: 0.0193
# Epoch 200/1000
# 41/41 [==============================] - 0s 258us/sample - loss: 0.0161
# Epoch 201/1000
# 41/41 [==============================] - 0s 322us/sample - loss: 0.0140
# Epoch 202/1000
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0150
# Epoch 203/1000
# 41/41 [==============================] - 0s 295us/sample - loss: 0.0140
# Epoch 204/1000
# 41/41 [==============================] - 0s 284us/sample - loss: 0.0218
# Epoch 205/1000
# 41/41 [==============================] - 0s 331us/sample - loss: 0.0133
# Epoch 206/1000
# 41/41 [==============================] - 0s 264us/sample - loss: 0.0299
# Epoch 207/1000
# 41/41 [==============================] - 0s 242us/sample - loss: 0.0210
# Epoch 208/1000
# 41/41 [==============================] - 0s 309us/sample - loss: 0.0155
# Epoch 209/1000
# 41/41 [==============================] - 0s 262us/sample - loss: 0.0206
# Epoch 210/1000
# 41/41 [==============================] - 0s 326us/sample - loss: 0.0149
# Epoch 211/1000
# 41/41 [==============================] - 0s 257us/sample - loss: 0.0131
# Epoch 212/1000
# 41/41 [==============================] - 0s 289us/sample - loss: 0.0133
# Epoch 213/1000
# 41/41 [==============================] - 0s 349us/sample - loss: 0.0184
# Epoch 214/1000
# 41/41 [==============================] - 0s 435us/sample - loss: 0.0394
# Epoch 215/1000
# 41/41 [==============================] - 0s 252us/sample - loss: 0.0152
# Epoch 216/1000
# 41/41 [==============================] - 0s 301us/sample - loss: 0.0132
# Epoch 217/1000
# 41/41 [==============================] - 0s 302us/sample - loss: 0.0195
# Epoch 218/1000
# 41/41 [==============================] - 0s 293us/sample - loss: 0.0218
# Epoch 219/1000
# 41/41 [==============================] - 0s 347us/sample - loss: 0.0157
# Epoch 220/1000
# 41/41 [==============================] - 0s 308us/sample - loss: 0.0143
# Epoch 221/1000
# 41/41 [==============================] - 0s 283us/sample - loss: 0.0140
# Epoch 222/1000
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0151
# Epoch 223/1000
# 41/41 [==============================] - 0s 389us/sample - loss: 0.0128
# Epoch 224/1000
# 41/41 [==============================] - 0s 368us/sample - loss: 0.0370
# Epoch 225/1000
# 41/41 [==============================] - 0s 340us/sample - loss: 0.0145
# Epoch 226/1000
# 41/41 [==============================] - 0s 351us/sample - loss: 0.0147
# Epoch 227/1000
# 41/41 [==============================] - 0s 349us/sample - loss: 0.0130
# Epoch 228/1000
# 41/41 [==============================] - 0s 600us/sample - loss: 0.0149
# Epoch 229/1000
# 41/41 [==============================] - 0s 263us/sample - loss: 0.0244
# Epoch 230/1000
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0250
# Epoch 231/1000
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0276
# Epoch 232/1000
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0243
# Epoch 233/1000
# 41/41 [==============================] - 0s 315us/sample - loss: 0.0133
# Epoch 234/1000
# 41/41 [==============================] - 0s 386us/sample - loss: 0.0154
# Epoch 235/1000
# 41/41 [==============================] - 0s 360us/sample - loss: 0.0289
# Epoch 236/1000
# 41/41 [==============================] - 0s 503us/sample - loss: 0.0151
# Epoch 237/1000
# 41/41 [==============================] - 0s 383us/sample - loss: 0.0130
# Epoch 238/1000
# 41/41 [==============================] - 0s 394us/sample - loss: 0.0166
# Epoch 239/1000
# 41/41 [==============================] - 0s 330us/sample - loss: 0.0175
# Epoch 240/1000
# 41/41 [==============================] - 0s 318us/sample - loss: 0.0160
# Epoch 241/1000
# 41/41 [==============================] - 0s 308us/sample - loss: 0.0397
# Epoch 242/1000
# 41/41 [==============================] - 0s 245us/sample - loss: 0.0173
# Epoch 243/1000
# 41/41 [==============================] - 0s 310us/sample - loss: 0.0134
# Epoch 244/1000
# 41/41 [==============================] - 0s 309us/sample - loss: 0.0225
# Epoch 245/1000
# 41/41 [==============================] - 0s 371us/sample - loss: 0.0146
# Epoch 246/1000
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0147
# Epoch 247/1000
# 41/41 [==============================] - 0s 300us/sample - loss: 0.0197
# Epoch 248/1000
# 41/41 [==============================] - 0s 299us/sample - loss: 0.0130
# Epoch 249/1000
# 41/41 [==============================] - 0s 360us/sample - loss: 0.0183
# Epoch 250/1000
# 41/41 [==============================] - 0s 284us/sample - loss: 0.0137
# Epoch 251/1000
# 41/41 [==============================] - 0s 298us/sample - loss: 0.0140
# Epoch 252/1000
# 41/41 [==============================] - 0s 234us/sample - loss: 0.0142
# Epoch 253/1000
# 41/41 [==============================] - 0s 298us/sample - loss: 0.0229
# Epoch 254/1000
# 41/41 [==============================] - 0s 327us/sample - loss: 0.0469
# Epoch 255/1000
# 41/41 [==============================] - 0s 374us/sample - loss: 0.0272
# Epoch 256/1000
# 41/41 [==============================] - 0s 279us/sample - loss: 0.0138
# Epoch 257/1000
# 41/41 [==============================] - 0s 265us/sample - loss: 0.0132
# Epoch 258/1000
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0133
# Epoch 259/1000
# 41/41 [==============================] - 0s 270us/sample - loss: 0.0156
# Epoch 260/1000
# 41/41 [==============================] - 0s 293us/sample - loss: 0.0412
# Epoch 261/1000
# 41/41 [==============================] - 0s 312us/sample - loss: 0.0141
# Epoch 262/1000
# 41/41 [==============================] - 0s 310us/sample - loss: 0.0131
# Epoch 263/1000
# 41/41 [==============================] - 0s 224us/sample - loss: 0.0187
# Epoch 264/1000
# 41/41 [==============================] - 0s 245us/sample - loss: 0.0198
# Epoch 265/1000
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0160
# Epoch 266/1000
# 41/41 [==============================] - 0s 297us/sample - loss: 0.0132
# Epoch 267/1000
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0333
# Epoch 268/1000
# 41/41 [==============================] - 0s 266us/sample - loss: 0.0202
# Epoch 269/1000
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0169
# Epoch 270/1000
# 41/41 [==============================] - 0s 262us/sample - loss: 0.0133
# Epoch 271/1000
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0139
# Epoch 272/1000
# 41/41 [==============================] - 0s 249us/sample - loss: 0.0416
# Epoch 273/1000
# 41/41 [==============================] - 0s 264us/sample - loss: 0.0226
# Epoch 274/1000
# 41/41 [==============================] - 0s 297us/sample - loss: 0.0130
# Epoch 275/1000
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0154
# Epoch 276/1000
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0136
# Epoch 277/1000
# 41/41 [==============================] - 0s 249us/sample - loss: 0.0142
# Epoch 278/1000
# 41/41 [==============================] - 0s 364us/sample - loss: 0.0132
# Epoch 279/1000
# 41/41 [==============================] - 0s 312us/sample - loss: 0.0196
# Epoch 280/1000
# 41/41 [==============================] - 0s 252us/sample - loss: 0.0336
# Epoch 281/1000
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0136
# Epoch 282/1000
# 41/41 [==============================] - 0s 346us/sample - loss: 0.0177
# Epoch 283/1000
# 41/41 [==============================] - 0s 360us/sample - loss: 0.0263
# Epoch 284/1000
# 41/41 [==============================] - 0s 269us/sample - loss: 0.0159
# Epoch 285/1000
# 41/41 [==============================] - 0s 340us/sample - loss: 0.0135
# Epoch 286/1000
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0203
# Epoch 287/1000
# 41/41 [==============================] - 0s 230us/sample - loss: 0.0355
# Epoch 288/1000
# 41/41 [==============================] - 0s 261us/sample - loss: 0.0159
# Epoch 289/1000
# 41/41 [==============================] - 0s 380us/sample - loss: 0.0143
# Epoch 290/1000
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0159
# Epoch 291/1000
# 41/41 [==============================] - 0s 283us/sample - loss: 0.0166
# Epoch 292/1000
# 41/41 [==============================] - 0s 292us/sample - loss: 0.0246
# Epoch 293/1000
# 41/41 [==============================] - 0s 240us/sample - loss: 0.0183
# Epoch 294/1000
# 41/41 [==============================] - 0s 349us/sample - loss: 0.0132
# Epoch 295/1000
# 41/41 [==============================] - 0s 380us/sample - loss: 0.0168
# Epoch 296/1000
# 41/41 [==============================] - 0s 269us/sample - loss: 0.0183
# Epoch 297/1000
# 41/41 [==============================] - 0s 317us/sample - loss: 0.0182
# Epoch 298/1000
# 41/41 [==============================] - 0s 283us/sample - loss: 0.0144
# Epoch 299/1000
# 41/41 [==============================] - 0s 240us/sample - loss: 0.0139
# Epoch 300/1000
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0154
# Epoch 301/1000
# 41/41 [==============================] - 0s 311us/sample - loss: 0.0512
# Epoch 302/1000
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0154
# Epoch 303/1000
# 41/41 [==============================] - 0s 268us/sample - loss: 0.0150
# Epoch 304/1000
# 41/41 [==============================] - 0s 340us/sample - loss: 0.0175
# Epoch 305/1000
# 41/41 [==============================] - 0s 260us/sample - loss: 0.0171
# Epoch 306/1000
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0156
# Epoch 307/1000
# 41/41 [==============================] - 0s 237us/sample - loss: 0.0338
# Epoch 308/1000
# 41/41 [==============================] - 0s 267us/sample - loss: 0.0131
# Epoch 309/1000
# 41/41 [==============================] - 0s 406us/sample - loss: 0.0134
# Epoch 310/1000
# 41/41 [==============================] - 0s 257us/sample - loss: 0.0138
# Epoch 311/1000
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0151
# Epoch 312/1000
# 41/41 [==============================] - 0s 408us/sample - loss: 0.0302
# Epoch 313/1000
# 41/41 [==============================] - 0s 257us/sample - loss: 0.0157
# Epoch 314/1000
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0132
# Epoch 315/1000
# 41/41 [==============================] - 0s 374us/sample - loss: 0.0142
# Epoch 316/1000
# 41/41 [==============================] - 0s 382us/sample - loss: 0.0247
# Epoch 317/1000
# 41/41 [==============================] - 0s 389us/sample - loss: 0.0274
# Epoch 318/1000
# 41/41 [==============================] - 0s 345us/sample - loss: 0.0141
# Epoch 319/1000
# 41/41 [==============================] - 0s 295us/sample - loss: 0.0217
# Epoch 320/1000
# 41/41 [==============================] - 0s 261us/sample - loss: 0.0163
# Epoch 321/1000
# 41/41 [==============================] - 0s 374us/sample - loss: 0.0142
# Epoch 322/1000
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0153
# Epoch 323/1000
# 41/41 [==============================] - 0s 389us/sample - loss: 0.0234
# Epoch 324/1000
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0248
# Epoch 325/1000
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0268
# Epoch 326/1000
# 41/41 [==============================] - 0s 378us/sample - loss: 0.0145
# Epoch 327/1000
# 41/41 [==============================] - 0s 359us/sample - loss: 0.0146
# Epoch 328/1000
# 41/41 [==============================] - 0s 312us/sample - loss: 0.0397
# Epoch 329/1000
# 41/41 [==============================] - 0s 374us/sample - loss: 0.0138
# Epoch 330/1000
# 41/41 [==============================] - 0s 332us/sample - loss: 0.0257
# Epoch 331/1000
# 41/41 [==============================] - 0s 337us/sample - loss: 0.0136
# Epoch 332/1000
# 41/41 [==============================] - 0s 304us/sample - loss: 0.0159
# Epoch 333/1000
# 41/41 [==============================] - 0s 304us/sample - loss: 0.0280
# Epoch 334/1000
# 41/41 [==============================] - 0s 290us/sample - loss: 0.0226
# Epoch 335/1000
# 41/41 [==============================] - 0s 268us/sample - loss: 0.0155
# Epoch 336/1000
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0157
# Epoch 337/1000
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0342
# Epoch 338/1000
# 41/41 [==============================] - 0s 344us/sample - loss: 0.0131
# Epoch 339/1000
# 41/41 [==============================] - 0s 369us/sample - loss: 0.0133
# Epoch 340/1000
# 41/41 [==============================] - 0s 253us/sample - loss: 0.0244
# Epoch 341/1000
# 41/41 [==============================] - 0s 318us/sample - loss: 0.0134
# Epoch 342/1000
# 41/41 [==============================] - 0s 336us/sample - loss: 0.0247
# Epoch 343/1000
# 41/41 [==============================] - 0s 353us/sample - loss: 0.0164
# Epoch 344/1000
# 41/41 [==============================] - 0s 437us/sample - loss: 0.0136
# Epoch 345/1000
# 41/41 [==============================] - 0s 371us/sample - loss: 0.0136
# Epoch 346/1000
# 41/41 [==============================] - 0s 406us/sample - loss: 0.0131
# Epoch 347/1000
# 41/41 [==============================] - 0s 299us/sample - loss: 0.0144
# Epoch 348/1000
# 41/41 [==============================] - 0s 396us/sample - loss: 0.0138
# Epoch 349/1000
# 41/41 [==============================] - 0s 345us/sample - loss: 0.0134
# Epoch 350/1000
# 41/41 [==============================] - 0s 353us/sample - loss: 0.0129
# Epoch 351/1000
# 41/41 [==============================] - 0s 311us/sample - loss: 0.0192
# Epoch 352/1000
# 41/41 [==============================] - 0s 311us/sample - loss: 0.0353
# Epoch 353/1000
# 41/41 [==============================] - 0s 348us/sample - loss: 0.0131
# Epoch 354/1000
# 41/41 [==============================] - 0s 347us/sample - loss: 0.0199
# Epoch 355/1000
# 41/41 [==============================] - 0s 289us/sample - loss: 0.0176
# Epoch 356/1000
# 41/41 [==============================] - 0s 434us/sample - loss: 0.0134
# Epoch 357/1000
# 41/41 [==============================] - 0s 542us/sample - loss: 0.0275
# Epoch 358/1000
# 41/41 [==============================] - 0s 579us/sample - loss: 0.0391
# Epoch 359/1000
# 41/41 [==============================] - 0s 315us/sample - loss: 0.0144
# Epoch 360/1000
# 41/41 [==============================] - 0s 394us/sample - loss: 0.0204
# Epoch 361/1000
# 41/41 [==============================] - 0s 356us/sample - loss: 0.0165
# Epoch 362/1000
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0143
# Epoch 363/1000
# 41/41 [==============================] - 0s 354us/sample - loss: 0.0179
# Epoch 364/1000
# 41/41 [==============================] - 0s 310us/sample - loss: 0.0217
# Epoch 365/1000
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0174
# Epoch 366/1000
# 41/41 [==============================] - 0s 292us/sample - loss: 0.0266
# Epoch 367/1000
# 41/41 [==============================] - 0s 298us/sample - loss: 0.0282
# Epoch 368/1000
# 41/41 [==============================] - 0s 361us/sample - loss: 0.0213
# Epoch 369/1000
# 41/41 [==============================] - 0s 409us/sample - loss: 0.0133
# Epoch 370/1000
# 41/41 [==============================] - 0s 290us/sample - loss: 0.0212
# Epoch 371/1000
# 41/41 [==============================] - 0s 343us/sample - loss: 0.0148
# Epoch 372/1000
# 41/41 [==============================] - 0s 326us/sample - loss: 0.0219
# Epoch 373/1000
# 41/41 [==============================] - 0s 308us/sample - loss: 0.0197
# Epoch 374/1000
# 41/41 [==============================] - 0s 424us/sample - loss: 0.0136
# Epoch 375/1000
# 41/41 [==============================] - 0s 352us/sample - loss: 0.0168
# Epoch 376/1000
# 41/41 [==============================] - 0s 363us/sample - loss: 0.0149
# Epoch 377/1000
# 41/41 [==============================] - 0s 379us/sample - loss: 0.0130
# Epoch 378/1000
# 41/41 [==============================] - 0s 352us/sample - loss: 0.0136
# Epoch 379/1000
# 41/41 [==============================] - 0s 358us/sample - loss: 0.0130
# Epoch 380/1000
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0206
# Epoch 381/1000
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0326
# Epoch 382/1000
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0137
# Epoch 383/1000
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0200
# Epoch 384/1000
# 41/41 [==============================] - 0s 398us/sample - loss: 0.0245
# Epoch 385/1000
# 41/41 [==============================] - 0s 258us/sample - loss: 0.0188
# Epoch 386/1000
# 41/41 [==============================] - 0s 380us/sample - loss: 0.0202
# Epoch 387/1000
# 41/41 [==============================] - 0s 228us/sample - loss: 0.0178
# Epoch 388/1000
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0152
# Epoch 389/1000
# 41/41 [==============================] - 0s 268us/sample - loss: 0.0146
# Epoch 390/1000
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0130
# Epoch 391/1000
# 41/41 [==============================] - 0s 319us/sample - loss: 0.0152
# Epoch 392/1000
# 41/41 [==============================] - 0s 317us/sample - loss: 0.0301
# Epoch 393/1000
# 41/41 [==============================] - 0s 386us/sample - loss: 0.0156
# Epoch 394/1000
# 41/41 [==============================] - 0s 312us/sample - loss: 0.0156
# Epoch 395/1000
# 41/41 [==============================] - 0s 468us/sample - loss: 0.0169
# Epoch 396/1000
# 41/41 [==============================] - 0s 236us/sample - loss: 0.0130
# Epoch 397/1000
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0232
# Epoch 398/1000
# 41/41 [==============================] - 0s 339us/sample - loss: 0.0366
# Epoch 399/1000
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0221
# Epoch 400/1000
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0130
# Epoch 401/1000
# 41/41 [==============================] - 0s 290us/sample - loss: 0.0150
# Epoch 402/1000
# 41/41 [==============================] - 0s 450us/sample - loss: 0.0141
# Epoch 403/1000
# 41/41 [==============================] - 0s 306us/sample - loss: 0.0144
# Epoch 404/1000
# 41/41 [==============================] - 0s 321us/sample - loss: 0.0182
# Epoch 405/1000
# 41/41 [==============================] - 0s 301us/sample - loss: 0.0229
# Epoch 406/1000
# 41/41 [==============================] - 0s 330us/sample - loss: 0.0177
# Epoch 407/1000
# 41/41 [==============================] - 0s 371us/sample - loss: 0.0287
# Epoch 408/1000
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0183
# Epoch 409/1000
# 41/41 [==============================] - 0s 344us/sample - loss: 0.0226
# Epoch 410/1000
# 41/41 [==============================] - 0s 492us/sample - loss: 0.0139
# Epoch 411/1000
# 41/41 [==============================] - 0s 310us/sample - loss: 0.0183
# Epoch 412/1000
# 41/41 [==============================] - 0s 250us/sample - loss: 0.0385
# Epoch 413/1000
# 41/41 [==============================] - 0s 355us/sample - loss: 0.0140
# Epoch 414/1000
# 41/41 [==============================] - 0s 381us/sample - loss: 0.0250
# Epoch 415/1000
# 41/41 [==============================] - 0s 288us/sample - loss: 0.0180
# Epoch 416/1000
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0134
# Epoch 417/1000
# 41/41 [==============================] - 0s 322us/sample - loss: 0.0238
# Epoch 418/1000
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0192
# Epoch 419/1000
# 41/41 [==============================] - 0s 593us/sample - loss: 0.0141
# Epoch 420/1000
# 41/41 [==============================] - 0s 467us/sample - loss: 0.0139
# Epoch 421/1000
# 41/41 [==============================] - 0s 392us/sample - loss: 0.0142
# Epoch 422/1000
# 41/41 [==============================] - 0s 392us/sample - loss: 0.0131
# Epoch 423/1000
# 41/41 [==============================] - 0s 352us/sample - loss: 0.0158
# Epoch 424/1000
# 41/41 [==============================] - 0s 237us/sample - loss: 0.0250
# Epoch 425/1000
# 41/41 [==============================] - 0s 244us/sample - loss: 0.0449
# Epoch 426/1000
# 41/41 [==============================] - 0s 241us/sample - loss: 0.0134
# Epoch 427/1000
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0181
# Epoch 428/1000
# 41/41 [==============================] - 0s 423us/sample - loss: 0.0175
# Epoch 429/1000
# 41/41 [==============================] - 0s 299us/sample - loss: 0.0145
# Epoch 430/1000
# 41/41 [==============================] - 0s 312us/sample - loss: 0.0130
# Epoch 431/1000
# 41/41 [==============================] - 0s 267us/sample - loss: 0.0132
# Epoch 432/1000
# 41/41 [==============================] - 0s 373us/sample - loss: 0.0131
# Epoch 433/1000
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0282
# Epoch 434/1000
# 41/41 [==============================] - 0s 302us/sample - loss: 0.0200
# Epoch 435/1000
# 41/41 [==============================] - 0s 289us/sample - loss: 0.0162
# Epoch 436/1000
# 41/41 [==============================] - 0s 339us/sample - loss: 0.0130
# Epoch 437/1000
# 41/41 [==============================] - 0s 436us/sample - loss: 0.0254
# Epoch 438/1000
# 41/41 [==============================] - 0s 350us/sample - loss: 0.0203
# Epoch 439/1000
# 41/41 [==============================] - 0s 269us/sample - loss: 0.0157
# Epoch 440/1000
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0141
# Epoch 441/1000
# 41/41 [==============================] - 0s 456us/sample - loss: 0.0131
# Epoch 442/1000
# 41/41 [==============================] - 0s 440us/sample - loss: 0.0216
# Epoch 443/1000
# 41/41 [==============================] - 0s 338us/sample - loss: 0.0437
# Epoch 444/1000
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0332
# Epoch 445/1000
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0144
# Epoch 446/1000
# 41/41 [==============================] - 0s 368us/sample - loss: 0.0200
# Epoch 447/1000
# 41/41 [==============================] - 0s 277us/sample - loss: 0.0227
# Epoch 448/1000
# 41/41 [==============================] - 0s 265us/sample - loss: 0.0264
# Epoch 449/1000
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0159
# Epoch 450/1000
# 41/41 [==============================] - 0s 283us/sample - loss: 0.0196
# Epoch 451/1000
# 41/41 [==============================] - 0s 221us/sample - loss: 0.0159
# Epoch 452/1000
# 41/41 [==============================] - 0s 283us/sample - loss: 0.0130
# Epoch 453/1000
# 41/41 [==============================] - 0s 273us/sample - loss: 0.0190
# Epoch 454/1000
# 41/41 [==============================] - 0s 273us/sample - loss: 0.0134
# Epoch 455/1000
# 41/41 [==============================] - 0s 273us/sample - loss: 0.0143
# Epoch 456/1000
# 41/41 [==============================] - 0s 364us/sample - loss: 0.0214
# Epoch 457/1000
# 41/41 [==============================] - 0s 386us/sample - loss: 0.0224
# Epoch 458/1000
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0346
# Epoch 459/1000
# 41/41 [==============================] - 0s 203us/sample - loss: 0.0180
# Epoch 460/1000
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0154
# Epoch 461/1000
# 41/41 [==============================] - 0s 365us/sample - loss: 0.0130
# Epoch 462/1000
# 41/41 [==============================] - 0s 321us/sample - loss: 0.0143
# Epoch 463/1000
# 41/41 [==============================] - 0s 225us/sample - loss: 0.0150
# Epoch 464/1000
# 41/41 [==============================] - 0s 215us/sample - loss: 0.0129
# Epoch 465/1000
# 41/41 [==============================] - 0s 244us/sample - loss: 0.0155
# Epoch 466/1000
# 41/41 [==============================] - 0s 211us/sample - loss: 0.0265
# Epoch 467/1000
# 41/41 [==============================] - 0s 214us/sample - loss: 0.0413
# Epoch 468/1000
# 41/41 [==============================] - 0s 249us/sample - loss: 0.0170
# Epoch 469/1000
# 41/41 [==============================] - 0s 496us/sample - loss: 0.0136
# Epoch 470/1000
# 41/41 [==============================] - 0s 329us/sample - loss: 0.0228
# Epoch 471/1000
# 41/41 [==============================] - 0s 336us/sample - loss: 0.0152
# Epoch 472/1000
# 41/41 [==============================] - 0s 329us/sample - loss: 0.0189
# Epoch 473/1000
# 41/41 [==============================] - 0s 339us/sample - loss: 0.0216
# Epoch 474/1000
# 41/41 [==============================] - 0s 462us/sample - loss: 0.0156
# Epoch 475/1000
# 41/41 [==============================] - 0s 375us/sample - loss: 0.0158
# Epoch 476/1000
# 41/41 [==============================] - 0s 390us/sample - loss: 0.0130
# Epoch 477/1000
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0217
# Epoch 478/1000
# 41/41 [==============================] - 0s 525us/sample - loss: 0.0279
# Epoch 479/1000
# 41/41 [==============================] - 0s 371us/sample - loss: 0.0179
# Epoch 480/1000
# 41/41 [==============================] - 0s 308us/sample - loss: 0.0320
# Epoch 481/1000
# 41/41 [==============================] - 0s 317us/sample - loss: 0.0130
# Epoch 482/1000
# 41/41 [==============================] - 0s 559us/sample - loss: 0.0133
# Epoch 483/1000
# 41/41 [==============================] - 0s 289us/sample - loss: 0.0278
# Epoch 484/1000
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0131
# Epoch 485/1000
# 41/41 [==============================] - 0s 284us/sample - loss: 0.0189
# Epoch 486/1000
# 41/41 [==============================] - 0s 308us/sample - loss: 0.0239
# Epoch 487/1000
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0177
# Epoch 488/1000
# 41/41 [==============================] - 0s 284us/sample - loss: 0.0352
# Epoch 489/1000
# 41/41 [==============================] - 0s 284us/sample - loss: 0.0195
# Epoch 490/1000
# 41/41 [==============================] - 0s 264us/sample - loss: 0.0139
# Epoch 491/1000
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0355
# Epoch 492/1000
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0134
# Epoch 493/1000
# 41/41 [==============================] - 0s 359us/sample - loss: 0.0130
# Epoch 494/1000
# 41/41 [==============================] - 0s 332us/sample - loss: 0.0172
# Epoch 495/1000
# 41/41 [==============================] - 0s 385us/sample - loss: 0.0143
# Epoch 496/1000
# 41/41 [==============================] - 0s 387us/sample - loss: 0.0149
# Epoch 497/1000
# 41/41 [==============================] - 0s 383us/sample - loss: 0.0149
# Epoch 498/1000
# 41/41 [==============================] - 0s 335us/sample - loss: 0.0185
# Epoch 499/1000
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0279
# Epoch 500/1000
# 41/41 [==============================] - 0s 223us/sample - loss: 0.0240
# Epoch 501/1000
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0197
# Epoch 502/1000
# 41/41 [==============================] - 0s 292us/sample - loss: 0.0165
# Epoch 503/1000
# 41/41 [==============================] - 0s 270us/sample - loss: 0.0164
# Epoch 504/1000
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0135
# Epoch 505/1000
# 41/41 [==============================] - 0s 276us/sample - loss: 0.0132
# Epoch 506/1000
# 41/41 [==============================] - 0s 292us/sample - loss: 0.0148
# Epoch 507/1000
# 41/41 [==============================] - 0s 309us/sample - loss: 0.0181
# Epoch 508/1000
# 41/41 [==============================] - 0s 315us/sample - loss: 0.0175
# Epoch 509/1000
# 41/41 [==============================] - 0s 392us/sample - loss: 0.0163
# Epoch 510/1000
# 41/41 [==============================] - 0s 371us/sample - loss: 0.0139
# Epoch 511/1000
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0130
# Epoch 512/1000
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0264
# Epoch 513/1000
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0369
# Epoch 514/1000
# 41/41 [==============================] - 0s 225us/sample - loss: 0.0162
# Epoch 515/1000
# 41/41 [==============================] - 0s 302us/sample - loss: 0.0155
# Epoch 516/1000
# 41/41 [==============================] - 0s 378us/sample - loss: 0.0233
# Epoch 517/1000
# 41/41 [==============================] - 0s 234us/sample - loss: 0.0132
# Epoch 518/1000
# 41/41 [==============================] - 0s 317us/sample - loss: 0.0139
# Epoch 519/1000
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0133
# Epoch 520/1000
# 41/41 [==============================] - 0s 258us/sample - loss: 0.0178
# Epoch 521/1000
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0335
# Epoch 522/1000
# 41/41 [==============================] - 0s 243us/sample - loss: 0.0412
# Epoch 523/1000
# 41/41 [==============================] - 0s 236us/sample - loss: 0.0199
# Epoch 524/1000
# 41/41 [==============================] - 0s 230us/sample - loss: 0.0189
# Epoch 525/1000
# 41/41 [==============================] - 0s 266us/sample - loss: 0.0163
# Epoch 526/1000
# 41/41 [==============================] - 0s 245us/sample - loss: 0.0163
# Epoch 527/1000
# 41/41 [==============================] - 0s 251us/sample - loss: 0.0132
# Epoch 528/1000
# 41/41 [==============================] - 0s 222us/sample - loss: 0.0145
# Epoch 529/1000
# 41/41 [==============================] - 0s 252us/sample - loss: 0.0144
# Epoch 530/1000
# 41/41 [==============================] - 0s 225us/sample - loss: 0.0144
# Epoch 531/1000
# 41/41 [==============================] - 0s 234us/sample - loss: 0.0209
# Epoch 532/1000
# 41/41 [==============================] - 0s 221us/sample - loss: 0.0176
# Epoch 533/1000
# 41/41 [==============================] - 0s 213us/sample - loss: 0.0345
# Epoch 534/1000
# 41/41 [==============================] - 0s 244us/sample - loss: 0.0151
# Epoch 535/1000
# 41/41 [==============================] - 0s 226us/sample - loss: 0.0139
# Epoch 536/1000
# 41/41 [==============================] - 0s 239us/sample - loss: 0.0144
# Epoch 537/1000
# 41/41 [==============================] - 0s 244us/sample - loss: 0.0133
# Epoch 538/1000
# 41/41 [==============================] - 0s 265us/sample - loss: 0.0259
# Epoch 539/1000
# 41/41 [==============================] - 0s 279us/sample - loss: 0.0405
# Epoch 540/1000
# 41/41 [==============================] - 0s 319us/sample - loss: 0.0182
# Epoch 541/1000
# 41/41 [==============================] - 0s 256us/sample - loss: 0.0134
# Epoch 542/1000
# 41/41 [==============================] - 0s 224us/sample - loss: 0.0200
# Epoch 543/1000
# 41/41 [==============================] - 0s 266us/sample - loss: 0.0154
# Epoch 544/1000
# 41/41 [==============================] - 0s 216us/sample - loss: 0.0152
# Epoch 545/1000
# 41/41 [==============================] - 0s 239us/sample - loss: 0.0135
# Epoch 546/1000
# 41/41 [==============================] - 0s 211us/sample - loss: 0.0129
# Epoch 547/1000
# 41/41 [==============================] - 0s 248us/sample - loss: 0.0204
# Epoch 548/1000
# 41/41 [==============================] - 0s 239us/sample - loss: 0.0132
# Epoch 549/1000
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0281
# Epoch 550/1000
# 41/41 [==============================] - 0s 387us/sample - loss: 0.0296
# Epoch 551/1000
# 41/41 [==============================] - 0s 346us/sample - loss: 0.0312
# Epoch 552/1000
# 41/41 [==============================] - 0s 346us/sample - loss: 0.0189
# Epoch 553/1000
# ...
# 41/41 [==============================] - 0s 274us/sample - loss: 0.0186
# Epoch 818/1000
# 41/41 [==============================] - 0s 389us/sample - loss: 0.0134
# Epoch 819/1000
# 41/41 [==============================] - 0s 456us/sample - loss: 0.0201
# Epoch 820/1000
# 41/41 [==============================] - 0s 348us/sample - loss: 0.0355
# Epoch 821/1000
# 41/41 [==============================] - 0s 267us/sample - loss: 0.0181
# Epoch 822/1000
# 41/41 [==============================] - 0s 330us/sample - loss: 0.0195
# Epoch 823/1000
# 41/41 [==============================] - 0s 273us/sample - loss: 0.0149
# Epoch 824/1000
# 41/41 [==============================] - 0s 205us/sample - loss: 0.0132
# Epoch 825/1000
# 41/41 [==============================] - 0s 290us/sample - loss: 0.0130
# Epoch 826/1000
# 41/41 [==============================] - 0s 243us/sample - loss: 0.0130
# Epoch 827/1000
# 41/41 [==============================] - 0s 258us/sample - loss: 0.0173
# Epoch 828/1000
# 41/41 [==============================] - 0s 287us/sample - loss: 0.0396
# Epoch 829/1000
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0418
# Epoch 830/1000
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0233
# Epoch 831/1000
# 41/41 [==============================] - 0s 428us/sample - loss: 0.0135
# Epoch 832/1000
# 41/41 [==============================] - 0s 306us/sample - loss: 0.0236
# Epoch 833/1000
# 41/41 [==============================] - 0s 264us/sample - loss: 0.0160
# Epoch 834/1000
# 41/41 [==============================] - 0s 331us/sample - loss: 0.0144
# Epoch 835/1000
# 41/41 [==============================] - 0s 340us/sample - loss: 0.0132
# Epoch 836/1000
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0133
# Epoch 837/1000
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0214
# Epoch 838/1000
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0288
# Epoch 839/1000
# 41/41 [==============================] - 0s 407us/sample - loss: 0.0171
# Epoch 840/1000
# 41/41 [==============================] - 0s 344us/sample - loss: 0.0143
# Epoch 841/1000
# 41/41 [==============================] - 0s 273us/sample - loss: 0.0264
# Epoch 842/1000
# 41/41 [==============================] - 0s 343us/sample - loss: 0.0172
# Epoch 843/1000
# 41/41 [==============================] - 0s 321us/sample - loss: 0.0168
# Epoch 844/1000
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0234
# Epoch 845/1000
# 41/41 [==============================] - 0s 338us/sample - loss: 0.0132
# Epoch 846/1000
# 41/41 [==============================] - 0s 277us/sample - loss: 0.0157
# Epoch 847/1000
# 41/41 [==============================] - 0s 261us/sample - loss: 0.0181
# Epoch 848/1000
# 41/41 [==============================] - 0s 273us/sample - loss: 0.0335
# Epoch 849/1000
# 41/41 [==============================] - 0s 298us/sample - loss: 0.0315
# Epoch 850/1000
# 41/41 [==============================] - 0s 326us/sample - loss: 0.0238
# Epoch 851/1000
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0202
# Epoch 852/1000
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0141
# Epoch 853/1000
# 41/41 [==============================] - 0s 223us/sample - loss: 0.0133
# Epoch 854/1000
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0198
# Epoch 855/1000
# 41/41 [==============================] - 0s 237us/sample - loss: 0.0214
# Epoch 856/1000
# 41/41 [==============================] - 0s 278us/sample - loss: 0.0133
# Epoch 857/1000
# 41/41 [==============================] - 0s 364us/sample - loss: 0.0130
# Epoch 858/1000
# 41/41 [==============================] - 0s 304us/sample - loss: 0.0178
# Epoch 859/1000
# 41/41 [==============================] - 0s 321us/sample - loss: 0.0325
# Epoch 860/1000
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0239
# Epoch 861/1000
# 41/41 [==============================] - 0s 236us/sample - loss: 0.0152
# Epoch 862/1000
# 41/41 [==============================] - 0s 237us/sample - loss: 0.0138
# Epoch 863/1000
# 41/41 [==============================] - 0s 223us/sample - loss: 0.0135
# Epoch 864/1000
# 41/41 [==============================] - 0s 246us/sample - loss: 0.0142
# Epoch 865/1000
# 41/41 [==============================] - 0s 253us/sample - loss: 0.0133
# Epoch 866/1000
# 41/41 [==============================] - 0s 268us/sample - loss: 0.0133
# Epoch 867/1000
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0297
# Epoch 868/1000
# 41/41 [==============================] - 0s 292us/sample - loss: 0.0296
# Epoch 869/1000
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0194
# Epoch 870/1000
# 41/41 [==============================] - 0s 305us/sample - loss: 0.0142
# Epoch 871/1000
# 41/41 [==============================] - 0s 285us/sample - loss: 0.0133
# Epoch 872/1000
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0239
# Epoch 873/1000
# 41/41 [==============================] - 0s 290us/sample - loss: 0.0278
# Epoch 874/1000
# 41/41 [==============================] - 0s 297us/sample - loss: 0.0140
# Epoch 875/1000
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0135
# Epoch 876/1000
# 41/41 [==============================] - 0s 254us/sample - loss: 0.0186
# Epoch 877/1000
# 41/41 [==============================] - 0s 339us/sample - loss: 0.0199
# Epoch 878/1000
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0132
# Epoch 879/1000
# 41/41 [==============================] - 0s 248us/sample - loss: 0.0315
# Epoch 880/1000
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0131
# Epoch 881/1000
# 41/41 [==============================] - 0s 283us/sample - loss: 0.0203
# Epoch 882/1000
# 41/41 [==============================] - 0s 268us/sample - loss: 0.0286
# Epoch 883/1000
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0151
# Epoch 884/1000
# 41/41 [==============================] - 0s 321us/sample - loss: 0.0289
# Epoch 885/1000
# 41/41 [==============================] - 0s 342us/sample - loss: 0.0299
# Epoch 886/1000
# 41/41 [==============================] - 0s 362us/sample - loss: 0.0165
# Epoch 887/1000
# 41/41 [==============================] - 0s 364us/sample - loss: 0.0131
# Epoch 888/1000
# 41/41 [==============================] - 0s 467us/sample - loss: 0.0188
# Epoch 889/1000
# 41/41 [==============================] - 0s 285us/sample - loss: 0.0148
# Epoch 890/1000
# 41/41 [==============================] - 0s 265us/sample - loss: 0.0236
# Epoch 891/1000
# 41/41 [==============================] - 0s 372us/sample - loss: 0.0261
# Epoch 892/1000
# 41/41 [==============================] - 0s 246us/sample - loss: 0.0241
# Epoch 893/1000
# 41/41 [==============================] - 0s 292us/sample - loss: 0.0145
# Epoch 894/1000
# 41/41 [==============================] - 0s 269us/sample - loss: 0.0214
# Epoch 895/1000
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0131
# Epoch 896/1000
# 41/41 [==============================] - 0s 269us/sample - loss: 0.0319
# Epoch 897/1000
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0397
# Epoch 898/1000
# 41/41 [==============================] - 0s 243us/sample - loss: 0.0190
# Epoch 899/1000
# 41/41 [==============================] - 0s 269us/sample - loss: 0.0141
# Epoch 900/1000
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0131
# Epoch 901/1000
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0144
# Epoch 902/1000
# 41/41 [==============================] - 0s 217us/sample - loss: 0.0206
# Epoch 903/1000
# 41/41 [==============================] - 0s 249us/sample - loss: 0.0164
# Epoch 904/1000
# 41/41 [==============================] - 0s 263us/sample - loss: 0.0242
# Epoch 905/1000
# 41/41 [==============================] - 0s 257us/sample - loss: 0.0270
# Epoch 906/1000
# 41/41 [==============================] - 0s 247us/sample - loss: 0.0152
# Epoch 907/1000
# 41/41 [==============================] - 0s 266us/sample - loss: 0.0134
# Epoch 908/1000
# 41/41 [==============================] - 0s 238us/sample - loss: 0.0139
# Epoch 909/1000
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0129
# Epoch 910/1000
# 41/41 [==============================] - 0s 403us/sample - loss: 0.0255
# Epoch 911/1000
# 41/41 [==============================] - 0s 430us/sample - loss: 0.0244
# Epoch 912/1000
# 41/41 [==============================] - 0s 442us/sample - loss: 0.0130
# Epoch 913/1000
# 41/41 [==============================] - 0s 417us/sample - loss: 0.0148
# Epoch 914/1000
# 41/41 [==============================] - 0s 346us/sample - loss: 0.0180
# Epoch 915/1000
# 41/41 [==============================] - 0s 322us/sample - loss: 0.0384
# Epoch 916/1000
# 41/41 [==============================] - 0s 311us/sample - loss: 0.0131
# Epoch 917/1000
# 41/41 [==============================] - 0s 431us/sample - loss: 0.0136
# Epoch 918/1000
# 41/41 [==============================] - 0s 278us/sample - loss: 0.0133
# Epoch 919/1000
# 41/41 [==============================] - 0s 281us/sample - loss: 0.0132
# Epoch 920/1000
# 41/41 [==============================] - 0s 419us/sample - loss: 0.0151
# Epoch 921/1000
# 41/41 [==============================] - 0s 332us/sample - loss: 0.0263
# Epoch 922/1000
# 41/41 [==============================] - 0s 348us/sample - loss: 0.0632
# Epoch 923/1000
# 41/41 [==============================] - 0s 287us/sample - loss: 0.0289
# Epoch 924/1000
# 41/41 [==============================] - 0s 277us/sample - loss: 0.0133
# Epoch 925/1000
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0130
# Epoch 926/1000
# 41/41 [==============================] - 0s 257us/sample - loss: 0.0131
# Epoch 927/1000
# 41/41 [==============================] - 0s 270us/sample - loss: 0.0160
# Epoch 928/1000
# 41/41 [==============================] - 0s 351us/sample - loss: 0.0306
# Epoch 929/1000
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0136
# Epoch 930/1000
# 41/41 [==============================] - 0s 253us/sample - loss: 0.0135
# Epoch 931/1000
# 41/41 [==============================] - 0s 312us/sample - loss: 0.0208
# Epoch 932/1000
# 41/41 [==============================] - 0s 299us/sample - loss: 0.0238
# Epoch 933/1000
# 41/41 [==============================] - 0s 254us/sample - loss: 0.0243
# Epoch 934/1000
# 41/41 [==============================] - 0s 255us/sample - loss: 0.0182
# Epoch 935/1000
# 41/41 [==============================] - 0s 305us/sample - loss: 0.0210
# Epoch 936/1000
# 41/41 [==============================] - 0s 317us/sample - loss: 0.0132
# Epoch 937/1000
# 41/41 [==============================] - 0s 214us/sample - loss: 0.0158
# Epoch 938/1000
# 41/41 [==============================] - 0s 215us/sample - loss: 0.0159
# Epoch 939/1000
# 41/41 [==============================] - 0s 242us/sample - loss: 0.0146
# Epoch 940/1000
# 41/41 [==============================] - 0s 230us/sample - loss: 0.0150
# Epoch 941/1000
# 41/41 [==============================] - 0s 235us/sample - loss: 0.0157
# Epoch 942/1000
# 41/41 [==============================] - 0s 203us/sample - loss: 0.0132
# Epoch 943/1000
# 41/41 [==============================] - 0s 195us/sample - loss: 0.0235
# Epoch 944/1000
# 41/41 [==============================] - 0s 222us/sample - loss: 0.0135
# Epoch 945/1000
# 41/41 [==============================] - 0s 208us/sample - loss: 0.0256
# Epoch 946/1000
# 41/41 [==============================] - 0s 218us/sample - loss: 0.0339
# Epoch 947/1000
# 41/41 [==============================] - 0s 230us/sample - loss: 0.0154
# Epoch 948/1000
# 41/41 [==============================] - 0s 199us/sample - loss: 0.0144
# Epoch 949/1000
# 41/41 [==============================] - 0s 191us/sample - loss: 0.0131
# Epoch 950/1000
# 41/41 [==============================] - 0s 255us/sample - loss: 0.0130
# Epoch 951/1000
# 41/41 [==============================] - 0s 219us/sample - loss: 0.0136
# Epoch 952/1000
# 41/41 [==============================] - 0s 228us/sample - loss: 0.0326
# Epoch 953/1000
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0134
# Epoch 954/1000
# 41/41 [==============================] - 0s 311us/sample - loss: 0.0131
# Epoch 955/1000
# 41/41 [==============================] - 0s 213us/sample - loss: 0.0137
# Epoch 956/1000
# 41/41 [==============================] - 0s 411us/sample - loss: 0.0130
# Epoch 957/1000
# 41/41 [==============================] - 0s 214us/sample - loss: 0.0210
# Epoch 958/1000
# 41/41 [==============================] - 0s 233us/sample - loss: 0.0378
# Epoch 959/1000
# 41/41 [==============================] - 0s 229us/sample - loss: 0.0217
# Epoch 960/1000
# 41/41 [==============================] - 0s 244us/sample - loss: 0.0143
# Epoch 961/1000
# 41/41 [==============================] - 0s 360us/sample - loss: 0.0239
# Epoch 962/1000
# 41/41 [==============================] - 0s 519us/sample - loss: 0.0135
# Epoch 963/1000
# 41/41 [==============================] - 0s 327us/sample - loss: 0.0132
# Epoch 964/1000
# 41/41 [==============================] - 0s 349us/sample - loss: 0.0130
# Epoch 965/1000
# 41/41 [==============================] - 0s 359us/sample - loss: 0.0153
# Epoch 966/1000
# 41/41 [==============================] - 0s 261us/sample - loss: 0.0143
# Epoch 967/1000
# 41/41 [==============================] - 0s 364us/sample - loss: 0.0232
# Epoch 968/1000
# 41/41 [==============================] - 0s 336us/sample - loss: 0.0165
# Epoch 969/1000
# 41/41 [==============================] - 0s 350us/sample - loss: 0.0222
# Epoch 970/1000
# 41/41 [==============================] - 0s 365us/sample - loss: 0.0130
# Epoch 971/1000
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0135
# Epoch 972/1000
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0162
# Epoch 973/1000
# 41/41 [==============================] - 0s 309us/sample - loss: 0.0590
# Epoch 974/1000
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0198
# Epoch 975/1000
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0163
# Epoch 976/1000
# 41/41 [==============================] - 0s 262us/sample - loss: 0.0147
# Epoch 977/1000
# 41/41 [==============================] - 0s 285us/sample - loss: 0.0160
# Epoch 978/1000
# 41/41 [==============================] - 0s 292us/sample - loss: 0.0391
# Epoch 979/1000
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0135
# Epoch 980/1000
# 41/41 [==============================] - 0s 249us/sample - loss: 0.0251
# Epoch 981/1000
# 41/41 [==============================] - 0s 277us/sample - loss: 0.0151
# Epoch 982/1000
# 41/41 [==============================] - 0s 236us/sample - loss: 0.0214
# Epoch 983/1000
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0134
# Epoch 984/1000
# 41/41 [==============================] - 0s 255us/sample - loss: 0.0136
# Epoch 985/1000
# 41/41 [==============================] - 0s 255us/sample - loss: 0.0140
# Epoch 986/1000
# 41/41 [==============================] - 0s 247us/sample - loss: 0.0130
# Epoch 987/1000
# 41/41 [==============================] - 0s 235us/sample - loss: 0.0152
# Epoch 988/1000
# 41/41 [==============================] - 0s 285us/sample - loss: 0.0307
# Epoch 989/1000
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0303
# Epoch 990/1000
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0184
# Epoch 991/1000
# 41/41 [==============================] - 0s 289us/sample - loss: 0.0136
# Epoch 992/1000
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0132
# Epoch 993/1000
# 41/41 [==============================] - 0s 340us/sample - loss: 0.0131
# Epoch 994/1000
# 41/41 [==============================] - 0s 278us/sample - loss: 0.0147
# Epoch 995/1000
# 41/41 [==============================] - 0s 390us/sample - loss: 0.0132
# Epoch 996/1000
# 41/41 [==============================] - 0s 243us/sample - loss: 0.0323
# Epoch 997/1000
# 41/41 [==============================] - 0s 244us/sample - loss: 0.0131
# Epoch 998/1000
# 41/41 [==============================] - 0s 256us/sample - loss: 0.0291
# Epoch 999/1000
# 41/41 [==============================] - 0s 252us/sample - loss: 0.0396
# Epoch 1000/1000
# 41/41 [==============================] - 0s 237us/sample - loss: 0.0151

# %% [markdown]
# Plot the loss history values to see if out model converged
#
# Because a model can have a history of many  different metrics over time, there is a history object which has a keys dictionary of
# metrics whose values were stored on each epoch. By plotting the values for the 'loss' key we can answer:
#
#
# 1.   Did the loss converge?
# 2.   How many epochs were required for the loss to converge?

# %%
train_hist.history['loss'].extend(train_hist_addn.history['loss'])   # add the addition epochs to the  training history
plot_loss(train_hist)
# Out:
# 1008
# 1000
# 2008

# %% [markdown]
# ### Visually Confirm Model after Additional Training
#
# As the  plot showed, the model's loss converged by 1000 epochs.  So the model should be trained to allow us to make accurate predictions.
#
# Let's again plot the predict the price for each siz.  And see if a line drawn with the learned weight and bias looks reasonable.

# %%
# Visualize data and regression line for learned weights
price_predicted_scaled =  model.predict(sf_train_scaled)
visualize_data(sf_scaler.inverse_transform(sf_train_scaled), 
               price_scaler.inverse_transform(price_train_scaled),
               sf_scaler.inverse_transform(sf_train_scaled), 
               price_scaler.inverse_transform(price_predicted_scaled),
               add_addn_reg_line=False)

# %% [markdown]
# **Yes.  The predicted line looks good!!!**

# %% [markdown]
# ## Test Trained Model
#
# Once we have the model trained, we want to the trained **with data not used to train the model!!!**
#
# The use of data not used in training to test the model is key.  If you use training data our testing results will be overly accurate and will not relect *"real-life"* usage of trained model to make predictions.

# %%
# Make a price prediction on data the model has never seen before, i.e. 
#    the Test data square footage
price_test_pred_scaled = model.predict(sf_test_scaled)

# calculate the mean squared error for the prediction, lower is better
from sklearn.metrics import mean_squared_error
print("prediction mean squared error:", 
          mean_squared_error(price_test_scaled, price_test_pred_scaled ))

# Visualize data and regression line 
#    plus the test square footable and predicted price
print('\nGreen triangles are Test actual Square footage and predicted Price')
visualize_data(sf_scaler.inverse_transform(sf_test_scaled),
               price_scaler.inverse_transform(price_test_scaled),
               sf_scaler.inverse_transform(sf_test_scaled), 
               price_scaler.inverse_transform(price_test_pred_scaled),
               add_addn_reg_line=False)
print('\nOur predicted values fit the data well!')
# Out:
# prediction mean squared error: 0.018414337894218463
#
# Green triangles are Test actual Square footage and predicted Price
# Our predicted values fit the data well!

# %% [markdown]
# ## What we have learned
#
#
#
# *   In Machine Learning we oftens spend considerable effort getting data in a form were our models can learn from the data.
# * A single neuron model can learn from data how to learn the appropriate slope and offset for the data
# *   Building this model was made easier by TensorFlow's implementation of the Keras library
# *   But to learn from the data we need to pass the data through the model enough times to get the loss to converge
# *   When we do that, the model learn the data's slope and offset.
# *  And when we apply these learned values, the predict prices from the test data's Square Footage are reasonable.

# %%
print(train_hist_addn.)
# Out:
#   File "<ipython-input-25-7db1c77bc504>", line 1
#     print(train_hist_addn.)
#                           ^
# SyntaxError: invalid syntax
