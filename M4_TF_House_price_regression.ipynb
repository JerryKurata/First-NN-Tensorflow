# %% [markdown]
# <a href="https://colab.research.google.com/github/JerryKurata/First-NN-Tensorflow/blob/master/TF_Getting_Started_M4_TF_House_price_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tensor Flow House Price Prediction
#
# This is a simple Tensorflow based notebook that applies the steps of the machine learning workflow to create, train, and test a model that will predict house prices.
#
# The notebook:
#
# *  Uses the steps of the machine workflow discussed in the course
# *  Illustrates how TensorFlow makes it easier to implement a machine learning solution
# *  Describes what is happening in various processing steps

# %% [markdown]
# ## Load correct version of TensorFlow
# Before we use TensorFlow we must load the correct version.  We want version 2.x.  To do this we execute the colab commands below.  Note that these commands **ONLY WORK IN COLAB.**

# %%
# Install TensorFlow using Colab's tensorflow_version command
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# ## Import Libraries
#
# We import TensorFlow, Numpy, and matplotlib libraries.
#
# Numpy is a powerful N-dimensional array library that
# allows us to easily create and manipulate arrays of data, and more!
#
# Numpy also allows us to convert TensorFlow's native data structures,
# to python native data types.
#
# matplotlib is a graphics plot library

# %%
# Import libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Check TensorFlow version
print("TensorFlow version:", tf.__version__)

# In colab we can get GPU acceleration if we install tensorflow-gpu 
#   and turn on GPU in Notebook settings
print("GPU is available:", tf.test.is_gpu_available())
# Out:
# TensorFlow version: 2.0.0
# GPU is available: True

# %% [markdown]
# ## Problem Statement
#
# Using example data, develop a model that predict house prices based on the size of a house.

# %% [markdown]
# ## Get Data
#
# In this example we will be using a truncated version of the Ames dataset that only contains information on homes sold in May 2010.
#
# ### About the Ames dataset.
#
# The Ames dataset is a widely avalable dataset that has become one of the standard datasets used when
# predicting home prices based on features of the home. It is based on the great work of Dean De Cock.  His rational
# and insight into this dataset can be found at http://jse.amstat.org/v19n3/decock.pdf.
#
#
# ### Getting the truncated dataset we use
# This data set can be found with the exercise files for this course.  The filename is **AmesHousing-05-2010.csv** .
#
# Before you run the code below, ensure you have downloaded the file to your computer.
#
# And when prompted, browse to the file's location on your computer and upload the file.
#
# *Warning: The file upload function will only show the file selection dialog for 30 seconds.  After that time it will close and cause an error because a file was not specified.  This timeout prevents the file dialog from blocking events in colab.  If you experience this timeout select the dataset file sooner.  It may help to move the dataset file to an easier to specify location such as your desktop.*

# %%
# You need to upload the file, AmesHousing-05-2001.csv provided with this course
from google.colab import files

# only load the single file
uploaded = files.upload()
# csv_filename contains the name of the first, and only file uploaded
csv_housefile = next(iter(uploaded.keys()))

print('User uploaded file "{name}" with length {length} bytes'.format(
      name=csv_housefile, length=len(uploaded[csv_housefile])))
# Out:
#      <input type="file" id="files-3fb05d7a-976e-477f-8376-3bc88f14f392" name="files[]" multiple disabled />
#      <output id="result-3fb05d7a-976e-477f-8376-3bc88f14f392">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AmesHousing-05-2010.csv to AmesHousing-05-2010 (2).csv
# User uploaded file "AmesHousing-05-2010.csv" with length 20140 bytes

# %% [markdown]
# ### Load the data into a pandas dataframe
#
# Pandas let's use easily review and manipulate the data.  If you are new to pandas, see https://pandas.pydata.org/ and the pandas 10 minute intro  http://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html to understand how pandas, and pandas dataframes makes working with tabular data in Python easy.

# %%
import io
import pandas as pd

# load the housing data into a pandas dataframe for easy viewing and manipulation
df_housing = pd.read_csv(csv_housefile)

# %% [markdown]
# ### Visualize the House Price data
#
# We use panda's  head method to look at the first few rows of data.  This will give use an understanding of the data we are working with.

# %%
# Visualize the dataset
 
# turn on option to display all columns, otherwise some columns may be hidden
pd.set_option('display.max_columns', None)  
# print the column names and first 5 rows of data
df_housing.head(5)
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1     13  527166040           60        RL          63.0      8402   Pave
# 2     38  528112020           20        RL          98.0     11478   Pave
# 3     56  528240070           60        RL           NaN      7851   Pave
# 4     59  528292020           60        RL           NaN      9505   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 2   NaN       Reg          Lvl    AllPub     Inside        Gtl      NridgHt
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      Gilbert
# 4   NaN       IR1          Lvl    AllPub    CulDSac        Gtl      Gilbert
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm      1Fam      1Story             6             5
# 1        Norm        Norm      1Fam      2Story             6             5
# 2        Norm        Norm      1Fam      1Story             8             5
# 3        Norm        Norm      1Fam      2Story             6             5
# 4        Norm        Norm      1Fam      2Story             7             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1960            1960        Hip   CompShg      BrkFace      Plywood
# 1        1998            1998      Gable   CompShg      VinylSd      VinylSd
# 2        2007            2008      Gable   CompShg      VinylSd      VinylSd
# 3        2002            2002      Gable   CompShg      VinylSd      VinylSd
# 4        2001            2001      Gable   CompShg      VinylSd      VinylSd
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0        Stone         112.0         TA         TA     CBlock        TA
# 1         None           0.0         TA         TA      PConc        Gd
# 2        Stone         200.0         Gd         TA      PConc        Ex
# 3          NaN           NaN         Gd         TA      PConc        Gd
# 4      BrkFace         180.0         Gd         TA      PConc        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        Gd            Gd            BLQ           639            Unf
# 1        TA            No            Unf             0            Unf
# 2        TA            No            GLQ          1218            Unf
# 3        TA            No            GLQ           625            Unf
# 4        TA            No            Unf             0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0             0          441           1080    GasA         Fa           Y
# 1             0          789            789    GasA         Gd           Y
# 2             0          486           1704    GasA         Ex           Y
# 3             0          235            860    GasA         Ex           Y
# 4             0          884            884    GasA         Ex           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr        1656           0                0         1656
# 1      SBrkr         789         676                0         1465
# 2      SBrkr        1704           0                0         1704
# 3      SBrkr         860        1100                0         1960
# 4      SBrkr         884        1151                0         2035
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0               1               0          1          0              3
# 1               0               0          2          1              3
# 2               1               0          2          0              3
# 3               1               0          2          1              4
# 4               0               0          2          1              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           TA              7        Typ           2
# 1              1           TA              7        Typ           1
# 2              1           Gd              7        Typ           1
# 3              1           Gd              8        Typ           2
# 4              1           Gd              8        Typ           1
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0           Gd      Attchd         1960.0           Fin            2
# 1           Gd      Attchd         1998.0           Fin            2
# 2           Gd      Attchd         2008.0           RFn            3
# 3           TA     BuiltIn         2002.0           Fin            2
# 4           Gd     BuiltIn         2001.0           Fin            2
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0          528          TA          TA           P           210
# 1          393          TA          TA           Y             0
# 2          772          TA          TA           Y             0
# 3          440          TA          TA           Y           288
# 4          434          TA          TA           Y           144
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area  \
# 0             62               0           0             0          0
# 1             75               0           0             0          0
# 2             50               0           0             0          0
# 3             48               0           0             0          0
# 4             48               0           0             0          0
#
#    Pool QC Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  \
# 0      NaN   NaN          NaN         0        5     2010       WD
# 1      NaN   NaN          NaN         0        5     2010       WD
# 2      NaN   NaN          NaN         0        5     2010       WD
# 3      NaN   NaN          NaN         0        5     2010       WD
# 4      NaN   NaN          NaN         0        5     2010       WD
#
#   Sale Condition  SalePrice
# 0         Normal     215000
# 1         Normal     180400
# 2         Normal     306000
# 3         Normal     216500
# 4         Normal     222500

# %% [markdown]
# Lots of feature columns.  From documentation of previous work with this data I believe that we can account for most of the difference in price (SalePrice) based on the size of the house.
#
# Looking through the columns we see the following features contains 'SF': BsmtFin SF 1, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF,  1st Flr SF, 2nd Flr SF, Low Qual Fin SF.
#
# A little more checking the data and we see in the data that there are summary columns for the bsement square footage and the above basement square footage.  Specific the feature columns Total Bsmt SF and Gr Liv Area sum the space as follows:
#
#
#
# >  Total Bsmt SF = BsmtFin SF 1 +  BsmtFin SF 2 + Bsmt Unf SF
#
# > Gr Liv Area =  1st Flr SF +  2nd Flr SF
#
# But, there is no feature for the total space in the house which is the sum of Basement and Upper floors or (Total Bsmt SF + Gr Liv Area ).  So let's add a new feature column containing this value called 'Total SF' to the dataset.
#
# But, before we proceed, let's see if the feature columns we are dependent upon contain missing values that will effect our results.  If so, we can remove the rows with missing columns or determine a way of imputing (updating the values) the missing columns.

# %%
 df_housing[['Total Bsmt SF', 'Gr Liv Area']].isnull().values.any()
# Out:
# False

# %% [markdown]
# No missing values, so additional work is required.  So we can add the new column Total SF.

# %%
# Add new feature column Total SF = Total Bsmt SF + Gr Liv Area
df_housing['Total SF'] = df_housing['Total Bsmt SF'] + df_housing['Gr Liv Area']

# %% [markdown]
# And we can check the numbers add and see associated sale price

# %%
# see the  bsmt and living area, total sf, and price columns
print(df_housing[['Total Bsmt SF', 'Gr Liv Area', 'Total SF', 'SalePrice']].head(5) )
# Out:
#    Total Bsmt SF  Gr Liv Area  Total SF  SalePrice
# 0           1080         1656      2736     215000
# 1            789         1465      2254     180400
# 2           1704         1704      3408     306000
# 3            860         1960      2820     216500
# 4            884         2035      2919     222500

# %% [markdown]
# ### Visualize the data.
#
# We visualize the data to give us some idea of the relationships between the various features.  To do that we create a  function to plot the data.

# %%
# This function visualizes our data and optionally a learned line
def visualize_data(x_vals, y_vals,
                   addn_x_vals=None, addn_y_vals=None, add_addn_reg_line=False):
  
  f, ax = plt.subplots(figsize=(8,8))
  plt.plot(x_vals, y_vals, 'ro')   # red dot for each data point
  # Optional plot another set of data points in a different color and symbol
  if (addn_x_vals is not None):
    plt.plot(addn_x_vals, addn_y_vals, 'g^') # green triangles for addition data points
    # Optionally, draw points of x,y pairs as green triangles.
    if (add_addn_reg_line):
      x_min_index = addn_x_vals.argmin()
      x_max_index = addn_x_vals.argmax()
      print(x_min_index,[addn_x_vals[x_min_index],addn_y_vals[x_min_index]] ) 
      print(x_max_index,[addn_x_vals[x_max_index],addn_y_vals[x_max_index]] ) 
      plt.plot([addn_x_vals[x_min_index],addn_y_vals[x_min_index]], 
               [addn_x_vals[x_max_index],addn_y_vals[x_max_index]], 
               'b-')  # draw a blue regression line
    
  plt.tick_params(axis='both', which='major', labelsize=14)
  
  plt.show()  # now plot the line showing the data and optionally the line

# %% [markdown]
# ### Visualizing Total SF and Price
#
# Using the visualize data function we can see the relationship between Total Square Feet (Total SF) and Price.

# %%
# Plot Price vs. Total SF
visualize_data(df_housing['Total SF'], df_housing['SalePrice'])

# %% [markdown]
# ### What does the visualization tell us?
#
# There seems to definitely be a **linear** relationship between the size of the house (as shown in Total SF) and Price.
#
# This suggests that we should perform Linear Regression. Where the relationship in the data is:
#  y = f(x).  Or in our case, Price = f(Total SF)
#
# With respect to defining the function f(x), we can sum the difference between traditional programming and Machine Learning as:
#
# * In tradition programming **we define what f(x)** is through structures such as equations or conditional statements
#
# * In Machine Learning, our model **learns from the data** what the function f(x) is.

# %% [markdown]
# ### Additional Pre-processing
#
# Before we can use our data, we want to do 2 tasks.
#
# 1.   Scale the data.  If values are on very different scales it will be difficult for the model to determine the relationships between features.  With our data, Square Footage(SF) ranges from 800-4200, and Prices range from 80,000 to 400,0000.  This means there is a nearly 100 times different in scale.  When we normalize we will reduce both qualtities to the same scale while preserving the differences between prices and sizes of homes.  This will help our model learn the relationship between price and size.
#
# 2.   Once we have this new dataset we want to split the dataset into 2 dataset.  One dataset will be used for training, and other dataset will used for testing.  **We never used testing data for training or training data for testing.**

# %%
# Scale data so SF and Sale Price are on similar scales with values 
#  from 0.0 to 1.0

from sklearn.preprocessing import MinMaxScaler

sf_scaler = MinMaxScaler()
sf_scaled = sf_scaler.fit_transform(df_housing['Total SF'].values.reshape(-1,1).astype(np.float64))
    
price_scaler = MinMaxScaler()
price_scaled = price_scaler.fit_transform(df_housing['SalePrice'].values.reshape(-1,1).astype(np.float64))

# %%
# Split the dataset into training dataset - 70%, Testing dateset - 30%
# we do this using the sklearn train_test_split method
from sklearn.model_selection import train_test_split

sf_train_scaled, sf_test_scaled, price_train_scaled, price_test_scaled = train_test_split(sf_scaled, 
                                                    price_scaled, 
                                                    test_size=0.3, random_state=42)

# %% [markdown]
# ## Create Model
#
# Here we create a model to learn from our data.  Our data looks linearly related, so can use a straight line
# to fit our data.  So we are going to create a model that is based on the equation of a straight line.
#
# And from our training data we will learn line once we can define this line's parameters we can use it's equation to predict the value of any future data.
#
# We use Tensorflow's Keras library to make the process easy.
#
# We create a sequential model with where the output of one layer becomes the input of the next layer.
#
# This model will is a simple Neural Network that implements y = wx + bias, where **w is a weight** and **bias is an offset**.
#
# *You may recognize from Geometry that y = wx + bias is the equation of straight line, where w is the slope and bias is the offset.  (See https://en.wikipedia.org/wiki/Line_(geometry) for a description.)*
#
# Therefore the goal is to use our data to train the model and learn the best values for w and bias.

# %% [markdown]
# ### Our Model
#
# We create our linear model using TensorFlow's Keras library.   Using Keras makes it easy for us to create, train, and evaluate our model.

# %%
# Create model using the TensorFlow Keras library
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=1, activation='linear', input_shape=[1],
                                kernel_initializer='random_uniform',
                                bias_initializer='zeros'))

# %% [markdown]
# ### Compile the model
#
# The model is now defined, but is not trained, or even ready to be trained.
#
# We will train the model by passing training data throught it and adjusting the weight and bias to reduce loss (error).  To perform these tasks we need a method for
# *  measuring loss and
# *  optimizing the values of the weight and bias to minimize this loss.
#
# There are many ways of measuring loss and optimizing the values.  We are going to use **Mean-Squared Error** ('mean_squared_error') to measure loss, and the process of **Stochasitic Gradient Descent** ('sgd') to find the optimal weight and bias to minimize the loss. *Note: We use the variant of sgd called mini-batch gradient descent.  And set the batch size in the fit method below.*
#
# We set these parameters for the model with the **compile** statement.

# %%
# Compile model
optimizer = "sgd"
model.compile(loss='mean_squared_error', optimizer=optimizer )

# %% [markdown]
# ## Train the Model
#
# Once the model has been defined and training methodology compiled we can train the model.  We do this with our training data.  We pass the training data through the model multiple times.  And on each pass the loss function we defined in the model compile will be used to calculate loss.  And the optimizer will be used to make adjustments to the weights and bias (just called weights from hear on) to minimize this error.
#
# We will repeat this process of calculating the loss with the current weights, measuring loss, and updating the weights to minimize loss for the specified number of **epochs**.  *We should see the loss decrease over time *
#
#
# We can set *verbose* flag to tell Keras how much information to show during the training process, 0 is none, 1 and 2 show more in-progress information.

# %%
# Train model using data
initial_epochs = 8
batch_size = 10
train_hist = model.fit(sf_train_scaled, price_train_scaled, 
                       epochs=initial_epochs, batch_size=batch_size, verbose=1)

# Is 8 epochs enough??? Maybe/Maybe not
# Out:
# Train on 41 samples
# Epoch 1/8
# 41/41 [==============================] - 0s 6ms/sample - loss: 0.1714
# Epoch 2/8
# 41/41 [==============================] - 0s 469us/sample - loss: 0.1372
# Epoch 3/8
# 41/41 [==============================] - 0s 432us/sample - loss: 0.1186
# Epoch 4/8
# 41/41 [==============================] - 0s 547us/sample - loss: 0.1034
# Epoch 5/8
# 41/41 [==============================] - 0s 454us/sample - loss: 0.0916
# Epoch 6/8
# 41/41 [==============================] - 0s 438us/sample - loss: 0.0820
# Epoch 7/8
# 41/41 [==============================] - 0s 428us/sample - loss: 0.0735
# Epoch 8/8
# 41/41 [==============================] - 0s 476us/sample - loss: 0.0673

# %% [markdown]
# ### Visually Confirm Model Training
#
# Our model learned the best weight and bias for our training data.  Let's see if a line drawn with these learned weight and bias looks reasonable.

# %%
#  predict the price with our trained model
price_predicted_scaled =  model.predict(sf_train_scaled)
visualize_data(sf_scaler.inverse_transform(sf_train_scaled), price_scaler.inverse_transform(price_train_scaled),
               sf_scaler.inverse_transform(sf_train_scaled), price_scaler.inverse_transform(price_predicted_scaled),
               add_addn_reg_line=False)
               
# If line looks bad, what do we do?

# %% [markdown]
# ### Evaluate Training
#
#
# Does not looks too good !!!
#
# What can we do?
#
# Should we change model architecture?  Does linear look incorrect?
#
# > NO
#
#
# What does loss look like?

# %%
def plot_loss(hist):
  # plot the loss
  plt.title('Loss History')
  plt.plot(hist.history['loss'])
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.show()

print(type(train_hist))
plot_loss(train_hist)
# Out:
# <class 'tensorflow.python.keras.callbacks.History'>

# %% [markdown]
# > LOSS STILL LOOK HIGH.  BUT IS DECREASING.
#
#
#
# Perhaps we have not converged.  What can we do????
#
# Train with more data?
#
# > NO.  WE HAVE ALL THE DATA
#
# Train for more epochs and check loss to ensure values have converged?
#  > YES!!!

# %% [markdown]
# ### Training more epochs
#
# The model is partially trained but the results are not great.  Let's go back and train the model some more.
#
# The question is how much more?
#
# We want to ensure the model is converged to a range of loss values.   So what we will see in the training output is the loss value starts to stay in a specific range .   It may go up or down a little, but there should be a stable range.

# %%
# Train model using data.  This time, train for additional epochs
# Also capture the changed over time in the history variable, train_hist so we 
#   can see if loss is converging
addn_epochs = 1200
train_hist_addn =model.fit(sf_train_scaled, price_train_scaled,  
                     epochs=addn_epochs, verbose=1)
# Out:
# Train on 41 samples
# Epoch 1/1200
# 41/41 [==============================] - 0s 411us/sample - loss: 0.0629
# Epoch 2/1200
# 41/41 [==============================] - 0s 222us/sample - loss: 0.0606
# Epoch 3/1200
# 41/41 [==============================] - 0s 234us/sample - loss: 0.0586
# Epoch 4/1200
# 41/41 [==============================] - 0s 287us/sample - loss: 0.0571
# Epoch 5/1200
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0558
# Epoch 6/1200
# 41/41 [==============================] - 0s 289us/sample - loss: 0.0544
# Epoch 7/1200
# 41/41 [==============================] - 0s 318us/sample - loss: 0.0532
# Epoch 8/1200
# 41/41 [==============================] - 0s 292us/sample - loss: 0.0522
# Epoch 9/1200
# 41/41 [==============================] - 0s 216us/sample - loss: 0.0511
# Epoch 10/1200
# 41/41 [==============================] - 0s 248us/sample - loss: 0.0502
# Epoch 11/1200
# 41/41 [==============================] - 0s 220us/sample - loss: 0.0495
# Epoch 12/1200
# 41/41 [==============================] - 0s 213us/sample - loss: 0.0486
# Epoch 13/1200
# 41/41 [==============================] - 0s 257us/sample - loss: 0.0479
# Epoch 14/1200
# 41/41 [==============================] - 0s 245us/sample - loss: 0.0473
# Epoch 15/1200
# 41/41 [==============================] - 0s 258us/sample - loss: 0.0467
# Epoch 16/1200
# 41/41 [==============================] - 0s 270us/sample - loss: 0.0462
# Epoch 17/1200
# 41/41 [==============================] - 0s 231us/sample - loss: 0.0456
# Epoch 18/1200
# 41/41 [==============================] - 0s 293us/sample - loss: 0.0449
# Epoch 19/1200
# 41/41 [==============================] - 0s 293us/sample - loss: 0.0445
# Epoch 20/1200
# 41/41 [==============================] - 0s 295us/sample - loss: 0.0441
# Epoch 21/1200
# 41/41 [==============================] - 0s 265us/sample - loss: 0.0434
# Epoch 22/1200
# 41/41 [==============================] - 0s 288us/sample - loss: 0.0428
# Epoch 23/1200
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0423
# Epoch 24/1200
# 41/41 [==============================] - 0s 245us/sample - loss: 0.0420
# Epoch 25/1200
# 41/41 [==============================] - 0s 246us/sample - loss: 0.0417
# Epoch 26/1200
# 41/41 [==============================] - 0s 214us/sample - loss: 0.0413
# Epoch 27/1200
# 41/41 [==============================] - 0s 219us/sample - loss: 0.0411
# Epoch 28/1200
# 41/41 [==============================] - 0s 261us/sample - loss: 0.0407
# Epoch 29/1200
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0405
# Epoch 30/1200
# 41/41 [==============================] - 0s 300us/sample - loss: 0.0402
# Epoch 31/1200
# 41/41 [==============================] - 0s 246us/sample - loss: 0.0400
# Epoch 32/1200
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0398
# Epoch 33/1200
# 41/41 [==============================] - 0s 264us/sample - loss: 0.0397
# Epoch 34/1200
# 41/41 [==============================] - 0s 247us/sample - loss: 0.0396
# Epoch 35/1200
# 41/41 [==============================] - 0s 267us/sample - loss: 0.0394
# Epoch 36/1200
# 41/41 [==============================] - 0s 228us/sample - loss: 0.0393
# Epoch 37/1200
# 41/41 [==============================] - 0s 249us/sample - loss: 0.0392
# Epoch 38/1200
# 41/41 [==============================] - 0s 240us/sample - loss: 0.0389
# Epoch 39/1200
# 41/41 [==============================] - 0s 228us/sample - loss: 0.0388
# Epoch 40/1200
# 41/41 [==============================] - 0s 265us/sample - loss: 0.0384
# Epoch 41/1200
# 41/41 [==============================] - 0s 276us/sample - loss: 0.0383
# Epoch 42/1200
# 41/41 [==============================] - 0s 268us/sample - loss: 0.0382
# Epoch 43/1200
# 41/41 [==============================] - 0s 414us/sample - loss: 0.0379
# Epoch 44/1200
# 41/41 [==============================] - 0s 345us/sample - loss: 0.0379
# Epoch 45/1200
# 41/41 [==============================] - 0s 266us/sample - loss: 0.0378
# Epoch 46/1200
# 41/41 [==============================] - 0s 269us/sample - loss: 0.0377
# Epoch 47/1200
# 41/41 [==============================] - 0s 521us/sample - loss: 0.0376
# Epoch 48/1200
# 41/41 [==============================] - 0s 380us/sample - loss: 0.0374
# Epoch 49/1200
# 41/41 [==============================] - 0s 317us/sample - loss: 0.0373
# Epoch 50/1200
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0371
# Epoch 51/1200
# 41/41 [==============================] - 0s 321us/sample - loss: 0.0370
# Epoch 52/1200
# 41/41 [==============================] - 0s 327us/sample - loss: 0.0369
# Epoch 53/1200
# 41/41 [==============================] - 0s 312us/sample - loss: 0.0368
# Epoch 54/1200
# 41/41 [==============================] - 0s 318us/sample - loss: 0.0367
# Epoch 55/1200
# 41/41 [==============================] - 0s 310us/sample - loss: 0.0366
# Epoch 56/1200
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0366
# Epoch 57/1200
# 41/41 [==============================] - 0s 262us/sample - loss: 0.0365
# Epoch 58/1200
# 41/41 [==============================] - 0s 354us/sample - loss: 0.0364
# Epoch 59/1200
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0364
# Epoch 60/1200
# 41/41 [==============================] - 0s 239us/sample - loss: 0.0362
# Epoch 61/1200
# 41/41 [==============================] - 0s 246us/sample - loss: 0.0362
# Epoch 62/1200
# 41/41 [==============================] - 0s 243us/sample - loss: 0.0361
# Epoch 63/1200
# 41/41 [==============================] - 0s 297us/sample - loss: 0.0361
# Epoch 64/1200
# 41/41 [==============================] - 0s 289us/sample - loss: 0.0360
# Epoch 65/1200
# 41/41 [==============================] - 0s 322us/sample - loss: 0.0360
# Epoch 66/1200
# 41/41 [==============================] - 0s 235us/sample - loss: 0.0359
# Epoch 67/1200
# 41/41 [==============================] - 0s 231us/sample - loss: 0.0358
# Epoch 68/1200
# 41/41 [==============================] - 0s 254us/sample - loss: 0.0358
# Epoch 69/1200
# 41/41 [==============================] - 0s 208us/sample - loss: 0.0357
# Epoch 70/1200
# 41/41 [==============================] - 0s 220us/sample - loss: 0.0357
# Epoch 71/1200
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0356
# Epoch 72/1200
# 41/41 [==============================] - 0s 311us/sample - loss: 0.0355
# Epoch 73/1200
# 41/41 [==============================] - 0s 312us/sample - loss: 0.0355
# Epoch 74/1200
# 41/41 [==============================] - 0s 330us/sample - loss: 0.0354
# Epoch 75/1200
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0353
# Epoch 76/1200
# 41/41 [==============================] - 0s 312us/sample - loss: 0.0352
# Epoch 77/1200
# 41/41 [==============================] - 0s 304us/sample - loss: 0.0352
# Epoch 78/1200
# 41/41 [==============================] - 0s 306us/sample - loss: 0.0351
# Epoch 79/1200
# 41/41 [==============================] - 0s 293us/sample - loss: 0.0351
# Epoch 80/1200
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0350
# Epoch 81/1200
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0350
# Epoch 82/1200
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0349
# Epoch 83/1200
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0349
# Epoch 84/1200
# 41/41 [==============================] - 0s 334us/sample - loss: 0.0348
# Epoch 85/1200
# 41/41 [==============================] - 0s 315us/sample - loss: 0.0347
# Epoch 86/1200
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0347
# Epoch 87/1200
# 41/41 [==============================] - 0s 310us/sample - loss: 0.0346
# Epoch 88/1200
# 41/41 [==============================] - 0s 351us/sample - loss: 0.0345
# Epoch 89/1200
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0345
# Epoch 90/1200
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0344
# Epoch 91/1200
# 41/41 [==============================] - 0s 259us/sample - loss: 0.0344
# Epoch 92/1200
# 41/41 [==============================] - 0s 302us/sample - loss: 0.0343
# Epoch 93/1200
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0342
# Epoch 94/1200
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0342
# Epoch 95/1200
# 41/41 [==============================] - 0s 311us/sample - loss: 0.0341
# Epoch 96/1200
# 41/41 [==============================] - 0s 306us/sample - loss: 0.0341
# Epoch 97/1200
# 41/41 [==============================] - 0s 215us/sample - loss: 0.0340
# Epoch 98/1200
# 41/41 [==============================] - 0s 259us/sample - loss: 0.0340
# Epoch 99/1200
# 41/41 [==============================] - 0s 385us/sample - loss: 0.0339
# Epoch 100/1200
# 41/41 [==============================] - 0s 259us/sample - loss: 0.0338
# Epoch 101/1200
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0338
# Epoch 102/1200
# 41/41 [==============================] - 0s 284us/sample - loss: 0.0337
# Epoch 103/1200
# 41/41 [==============================] - 0s 298us/sample - loss: 0.0337
# Epoch 104/1200
# 41/41 [==============================] - 0s 368us/sample - loss: 0.0336
# Epoch 105/1200
# 41/41 [==============================] - 0s 219us/sample - loss: 0.0336
# Epoch 106/1200
# 41/41 [==============================] - 0s 255us/sample - loss: 0.0335
# Epoch 107/1200
# 41/41 [==============================] - 0s 283us/sample - loss: 0.0334
# Epoch 108/1200
# 41/41 [==============================] - 0s 242us/sample - loss: 0.0334
# Epoch 109/1200
# 41/41 [==============================] - 0s 208us/sample - loss: 0.0333
# Epoch 110/1200
# 41/41 [==============================] - 0s 245us/sample - loss: 0.0333
# Epoch 111/1200
# 41/41 [==============================] - 0s 232us/sample - loss: 0.0332
# Epoch 112/1200
# 41/41 [==============================] - 0s 252us/sample - loss: 0.0332
# Epoch 113/1200
# 41/41 [==============================] - 0s 261us/sample - loss: 0.0331
# Epoch 114/1200
# 41/41 [==============================] - 0s 229us/sample - loss: 0.0331
# Epoch 115/1200
# 41/41 [==============================] - 0s 234us/sample - loss: 0.0330
# Epoch 116/1200
# 41/41 [==============================] - 0s 237us/sample - loss: 0.0330
# Epoch 117/1200
# 41/41 [==============================] - 0s 249us/sample - loss: 0.0329
# Epoch 118/1200
# 41/41 [==============================] - 0s 241us/sample - loss: 0.0329
# Epoch 119/1200
# 41/41 [==============================] - 0s 366us/sample - loss: 0.0328
# Epoch 120/1200
# 41/41 [==============================] - 0s 431us/sample - loss: 0.0328
# Epoch 121/1200
# 41/41 [==============================] - 0s 423us/sample - loss: 0.0327
# Epoch 122/1200
# 41/41 [==============================] - 0s 441us/sample - loss: 0.0326
# Epoch 123/1200
# 41/41 [==============================] - 0s 410us/sample - loss: 0.0326
# Epoch 124/1200
# 41/41 [==============================] - 0s 424us/sample - loss: 0.0325
# Epoch 125/1200
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0325
# Epoch 126/1200
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0324
# Epoch 127/1200
# 41/41 [==============================] - 0s 315us/sample - loss: 0.0324
# Epoch 128/1200
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0324
# Epoch 129/1200
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0323
# Epoch 130/1200
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0322
# Epoch 131/1200
# 41/41 [==============================] - 0s 281us/sample - loss: 0.0322
# Epoch 132/1200
# 41/41 [==============================] - 0s 290us/sample - loss: 0.0321
# Epoch 133/1200
# 41/41 [==============================] - 0s 289us/sample - loss: 0.0320
# Epoch 134/1200
# 41/41 [==============================] - 0s 243us/sample - loss: 0.0320
# Epoch 135/1200
# 41/41 [==============================] - 0s 269us/sample - loss: 0.0319
# Epoch 136/1200
# 41/41 [==============================] - 0s 259us/sample - loss: 0.0319
# Epoch 137/1200
# 41/41 [==============================] - 0s 268us/sample - loss: 0.0318
# Epoch 138/1200
# 41/41 [==============================] - 0s 263us/sample - loss: 0.0318
# Epoch 139/1200
# 41/41 [==============================] - 0s 330us/sample - loss: 0.0317
# Epoch 140/1200
# 41/41 [==============================] - 0s 321us/sample - loss: 0.0317
# Epoch 141/1200
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0316
# Epoch 142/1200
# 41/41 [==============================] - 0s 337us/sample - loss: 0.0316
# Epoch 143/1200
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0315
# Epoch 144/1200
# 41/41 [==============================] - 0s 416us/sample - loss: 0.0315
# Epoch 145/1200
# 41/41 [==============================] - 0s 438us/sample - loss: 0.0315
# Epoch 146/1200
# 41/41 [==============================] - 0s 353us/sample - loss: 0.0314
# Epoch 147/1200
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0314
# Epoch 148/1200
# 41/41 [==============================] - 0s 327us/sample - loss: 0.0313
# Epoch 149/1200
# 41/41 [==============================] - 0s 245us/sample - loss: 0.0312
# Epoch 150/1200
# 41/41 [==============================] - 0s 310us/sample - loss: 0.0312
# Epoch 151/1200
# 41/41 [==============================] - 0s 326us/sample - loss: 0.0311
# Epoch 152/1200
# 41/41 [==============================] - 0s 413us/sample - loss: 0.0311
# Epoch 153/1200
# 41/41 [==============================] - 0s 338us/sample - loss: 0.0310
# Epoch 154/1200
# 41/41 [==============================] - 0s 310us/sample - loss: 0.0310
# Epoch 155/1200
# 41/41 [==============================] - 0s 405us/sample - loss: 0.0309
# Epoch 156/1200
# 41/41 [==============================] - 0s 220us/sample - loss: 0.0309
# Epoch 157/1200
# 41/41 [==============================] - 0s 245us/sample - loss: 0.0308
# Epoch 158/1200
# 41/41 [==============================] - 0s 248us/sample - loss: 0.0308
# Epoch 159/1200
# 41/41 [==============================] - 0s 301us/sample - loss: 0.0307
# Epoch 160/1200
# 41/41 [==============================] - 0s 514us/sample - loss: 0.0307
# Epoch 161/1200
# 41/41 [==============================] - 0s 377us/sample - loss: 0.0306
# Epoch 162/1200
# 41/41 [==============================] - 0s 429us/sample - loss: 0.0305
# Epoch 163/1200
# 41/41 [==============================] - 0s 241us/sample - loss: 0.0305
# Epoch 164/1200
# 41/41 [==============================] - 0s 262us/sample - loss: 0.0305
# Epoch 165/1200
# 41/41 [==============================] - 0s 289us/sample - loss: 0.0304
# Epoch 166/1200
# 41/41 [==============================] - 0s 249us/sample - loss: 0.0304
# Epoch 167/1200
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0303
# Epoch 168/1200
# 41/41 [==============================] - 0s 288us/sample - loss: 0.0302
# Epoch 169/1200
# 41/41 [==============================] - 0s 260us/sample - loss: 0.0302
# Epoch 170/1200
# 41/41 [==============================] - 0s 323us/sample - loss: 0.0301
# Epoch 171/1200
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0301
# Epoch 172/1200
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0300
# Epoch 173/1200
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0300
# Epoch 174/1200
# 41/41 [==============================] - 0s 266us/sample - loss: 0.0300
# Epoch 175/1200
# 41/41 [==============================] - 0s 244us/sample - loss: 0.0299
# Epoch 176/1200
# 41/41 [==============================] - 0s 266us/sample - loss: 0.0299
# Epoch 177/1200
# 41/41 [==============================] - 0s 343us/sample - loss: 0.0298
# Epoch 178/1200
# 41/41 [==============================] - 0s 331us/sample - loss: 0.0298
# Epoch 179/1200
# 41/41 [==============================] - 0s 332us/sample - loss: 0.0297
# Epoch 180/1200
# 41/41 [==============================] - 0s 350us/sample - loss: 0.0297
# Epoch 181/1200
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0296
# Epoch 182/1200
# 41/41 [==============================] - 0s 372us/sample - loss: 0.0296
# Epoch 183/1200
# 41/41 [==============================] - 0s 523us/sample - loss: 0.0295
# Epoch 184/1200
# 41/41 [==============================] - 0s 361us/sample - loss: 0.0295
# Epoch 185/1200
# 41/41 [==============================] - 0s 424us/sample - loss: 0.0294
# Epoch 186/1200
# 41/41 [==============================] - 0s 337us/sample - loss: 0.0294
# Epoch 187/1200
# 41/41 [==============================] - 0s 287us/sample - loss: 0.0294
# Epoch 188/1200
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0293
# Epoch 189/1200
# 41/41 [==============================] - 0s 340us/sample - loss: 0.0293
# Epoch 190/1200
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0292
# Epoch 191/1200
# 41/41 [==============================] - 0s 368us/sample - loss: 0.0292
# Epoch 192/1200
# 41/41 [==============================] - 0s 304us/sample - loss: 0.0291
# Epoch 193/1200
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0291
# Epoch 194/1200
# 41/41 [==============================] - 0s 322us/sample - loss: 0.0290
# Epoch 195/1200
# 41/41 [==============================] - 0s 321us/sample - loss: 0.0290
# Epoch 196/1200
# 41/41 [==============================] - 0s 301us/sample - loss: 0.0290
# Epoch 197/1200
# 41/41 [==============================] - 0s 257us/sample - loss: 0.0289
# Epoch 198/1200
# 41/41 [==============================] - 0s 270us/sample - loss: 0.0289
# Epoch 199/1200
# 41/41 [==============================] - 0s 276us/sample - loss: 0.0288
# Epoch 200/1200
# 41/41 [==============================] - 0s 432us/sample - loss: 0.0288
# Epoch 201/1200
# 41/41 [==============================] - 0s 254us/sample - loss: 0.0287
# Epoch 202/1200
# 41/41 [==============================] - 0s 249us/sample - loss: 0.0287
# Epoch 203/1200
# 41/41 [==============================] - 0s 251us/sample - loss: 0.0287
# Epoch 204/1200
# 41/41 [==============================] - 0s 308us/sample - loss: 0.0286
# Epoch 205/1200
# 41/41 [==============================] - 0s 192us/sample - loss: 0.0286
# Epoch 206/1200
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0285
# Epoch 207/1200
# 41/41 [==============================] - 0s 269us/sample - loss: 0.0285
# Epoch 208/1200
# 41/41 [==============================] - 0s 284us/sample - loss: 0.0284
# Epoch 209/1200
# 41/41 [==============================] - 0s 268us/sample - loss: 0.0284
# Epoch 210/1200
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0283
# Epoch 211/1200
# 41/41 [==============================] - 0s 265us/sample - loss: 0.0283
# Epoch 212/1200
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0282
# Epoch 213/1200
# 41/41 [==============================] - 0s 265us/sample - loss: 0.0282
# Epoch 214/1200
# 41/41 [==============================] - 0s 247us/sample - loss: 0.0282
# Epoch 215/1200
# 41/41 [==============================] - 0s 236us/sample - loss: 0.0281
# Epoch 216/1200
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0281
# Epoch 217/1200
# 41/41 [==============================] - 0s 255us/sample - loss: 0.0281
# Epoch 218/1200
# 41/41 [==============================] - 0s 246us/sample - loss: 0.0280
# Epoch 219/1200
# 41/41 [==============================] - 0s 259us/sample - loss: 0.0279
# Epoch 220/1200
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0279
# Epoch 221/1200
# 41/41 [==============================] - 0s 389us/sample - loss: 0.0279
# Epoch 222/1200
# 41/41 [==============================] - 0s 429us/sample - loss: 0.0278
# Epoch 223/1200
# 41/41 [==============================] - 0s 379us/sample - loss: 0.0278
# Epoch 224/1200
# 41/41 [==============================] - 0s 393us/sample - loss: 0.0277
# Epoch 225/1200
# 41/41 [==============================] - 0s 240us/sample - loss: 0.0277
# Epoch 226/1200
# 41/41 [==============================] - 0s 281us/sample - loss: 0.0277
# Epoch 227/1200
# 41/41 [==============================] - 0s 304us/sample - loss: 0.0276
# Epoch 228/1200
# 41/41 [==============================] - 0s 292us/sample - loss: 0.0276
# Epoch 229/1200
# 41/41 [==============================] - 0s 281us/sample - loss: 0.0276
# Epoch 230/1200
# 41/41 [==============================] - 0s 329us/sample - loss: 0.0275
# Epoch 231/1200
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0275
# Epoch 232/1200
# 41/41 [==============================] - 0s 373us/sample - loss: 0.0274
# Epoch 233/1200
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0274
# Epoch 234/1200
# 41/41 [==============================] - 0s 273us/sample - loss: 0.0273
# Epoch 235/1200
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0273
# Epoch 236/1200
# 41/41 [==============================] - 0s 285us/sample - loss: 0.0273
# Epoch 237/1200
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0272
# Epoch 238/1200
# 41/41 [==============================] - 0s 273us/sample - loss: 0.0272
# Epoch 239/1200
# 41/41 [==============================] - 0s 244us/sample - loss: 0.0271
# Epoch 240/1200
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0271
# Epoch 241/1200
# 41/41 [==============================] - 0s 300us/sample - loss: 0.0271
# Epoch 242/1200
# 41/41 [==============================] - 0s 375us/sample - loss: 0.0270
# Epoch 243/1200
# 41/41 [==============================] - 0s 385us/sample - loss: 0.0270
# Epoch 244/1200
# 41/41 [==============================] - 0s 352us/sample - loss: 0.0269
# Epoch 245/1200
# 41/41 [==============================] - 0s 425us/sample - loss: 0.0269
# Epoch 246/1200
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0269
# Epoch 247/1200
# 41/41 [==============================] - 0s 353us/sample - loss: 0.0268
# Epoch 248/1200
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0268
# Epoch 249/1200
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0268
# Epoch 250/1200
# 41/41 [==============================] - 0s 261us/sample - loss: 0.0267
# Epoch 251/1200
# 41/41 [==============================] - 0s 427us/sample - loss: 0.0267
# Epoch 252/1200
# 41/41 [==============================] - 0s 340us/sample - loss: 0.0266
# Epoch 253/1200
# 41/41 [==============================] - 0s 329us/sample - loss: 0.0266
# Epoch 254/1200
# 41/41 [==============================] - 0s 344us/sample - loss: 0.0266
# Epoch 255/1200
# 41/41 [==============================] - 0s 254us/sample - loss: 0.0265
# Epoch 256/1200
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0265
# Epoch 257/1200
# 41/41 [==============================] - 0s 267us/sample - loss: 0.0265
# Epoch 258/1200
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0265
# Epoch 259/1200
# 41/41 [==============================] - 0s 242us/sample - loss: 0.0264
# Epoch 260/1200
# 41/41 [==============================] - 0s 256us/sample - loss: 0.0264
# Epoch 261/1200
# 41/41 [==============================] - 0s 375us/sample - loss: 0.0264
# Epoch 262/1200
# 41/41 [==============================] - 0s 297us/sample - loss: 0.0263
# Epoch 263/1200
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0263
# Epoch 264/1200
# 41/41 [==============================] - 0s 246us/sample - loss: 0.0263
# Epoch 265/1200
# 41/41 [==============================] - 0s 257us/sample - loss: 0.0262
# Epoch 266/1200
# 41/41 [==============================] - 0s 255us/sample - loss: 0.0262
# Epoch 267/1200
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0261
# Epoch 268/1200
# 41/41 [==============================] - 0s 403us/sample - loss: 0.0261
# Epoch 269/1200
# 41/41 [==============================] - 0s 355us/sample - loss: 0.0261
# Epoch 270/1200
# 41/41 [==============================] - 0s 319us/sample - loss: 0.0260
# Epoch 271/1200
# 41/41 [==============================] - 0s 242us/sample - loss: 0.0260
# Epoch 272/1200
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0260
# Epoch 273/1200
# 41/41 [==============================] - 0s 279us/sample - loss: 0.0259
# Epoch 274/1200
# 41/41 [==============================] - 0s 269us/sample - loss: 0.0259
# Epoch 275/1200
# 41/41 [==============================] - 0s 251us/sample - loss: 0.0259
# Epoch 276/1200
# 41/41 [==============================] - 0s 250us/sample - loss: 0.0258
# Epoch 277/1200
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0258
# Epoch 278/1200
# 41/41 [==============================] - 0s 297us/sample - loss: 0.0258
# Epoch 279/1200
# 41/41 [==============================] - 0s 251us/sample - loss: 0.0257
# Epoch 280/1200
# 41/41 [==============================] - 0s 252us/sample - loss: 0.0257
# Epoch 281/1200
# 41/41 [==============================] - 0s 258us/sample - loss: 0.0256
# Epoch 282/1200
# 41/41 [==============================] - 0s 319us/sample - loss: 0.0256
# Epoch 283/1200
# 41/41 [==============================] - 0s 340us/sample - loss: 0.0256
# Epoch 284/1200
# 41/41 [==============================] - 0s 373us/sample - loss: 0.0255
# Epoch 285/1200
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0255
# Epoch 286/1200
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0255
# Epoch 287/1200
# 41/41 [==============================] - 0s 279us/sample - loss: 0.0254
# Epoch 288/1200
# 41/41 [==============================] - 0s 255us/sample - loss: 0.0254
# Epoch 289/1200
# 41/41 [==============================] - 0s 253us/sample - loss: 0.0254
# Epoch 290/1200
# 41/41 [==============================] - 0s 250us/sample - loss: 0.0253
# Epoch 291/1200
# 41/41 [==============================] - 0s 231us/sample - loss: 0.0253
# Epoch 292/1200
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0252
# Epoch 293/1200
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0252
# Epoch 294/1200
# 41/41 [==============================] - 0s 300us/sample - loss: 0.0252
# Epoch 295/1200
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0251
# Epoch 296/1200
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0251
# Epoch 297/1200
# 41/41 [==============================] - 0s 298us/sample - loss: 0.0251
# Epoch 298/1200
# 41/41 [==============================] - 0s 360us/sample - loss: 0.0250
# Epoch 299/1200
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0250
# Epoch 300/1200
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0250
# Epoch 301/1200
# 41/41 [==============================] - 0s 388us/sample - loss: 0.0249
# Epoch 302/1200
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0249
# Epoch 303/1200
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0249
# Epoch 304/1200
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0248
# Epoch 305/1200
# 41/41 [==============================] - 0s 359us/sample - loss: 0.0248
# Epoch 306/1200
# 41/41 [==============================] - 0s 391us/sample - loss: 0.0248
# Epoch 307/1200
# 41/41 [==============================] - 0s 322us/sample - loss: 0.0247
# Epoch 308/1200
# 41/41 [==============================] - 0s 234us/sample - loss: 0.0247
# Epoch 309/1200
# 41/41 [==============================] - 0s 336us/sample - loss: 0.0247
# Epoch 310/1200
# 41/41 [==============================] - 0s 306us/sample - loss: 0.0247
# Epoch 311/1200
# 41/41 [==============================] - 0s 309us/sample - loss: 0.0246
# Epoch 312/1200
# 41/41 [==============================] - 0s 458us/sample - loss: 0.0246
# Epoch 313/1200
# 41/41 [==============================] - 0s 414us/sample - loss: 0.0246
# Epoch 314/1200
# 41/41 [==============================] - 0s 346us/sample - loss: 0.0245
# Epoch 315/1200
# 41/41 [==============================] - 0s 306us/sample - loss: 0.0245
# Epoch 316/1200
# 41/41 [==============================] - 0s 408us/sample - loss: 0.0245
# Epoch 317/1200
# 41/41 [==============================] - 0s 339us/sample - loss: 0.0244
# Epoch 318/1200
# 41/41 [==============================] - 0s 214us/sample - loss: 0.0244
# Epoch 319/1200
# 41/41 [==============================] - 0s 509us/sample - loss: 0.0244
# Epoch 320/1200
# 41/41 [==============================] - 0s 332us/sample - loss: 0.0243
# Epoch 321/1200
# 41/41 [==============================] - 0s 277us/sample - loss: 0.0243
# Epoch 322/1200
# 41/41 [==============================] - 0s 277us/sample - loss: 0.0243
# Epoch 323/1200
# 41/41 [==============================] - 0s 315us/sample - loss: 0.0242
# Epoch 324/1200
# 41/41 [==============================] - 0s 301us/sample - loss: 0.0242
# Epoch 325/1200
# 41/41 [==============================] - 0s 341us/sample - loss: 0.0242
# Epoch 326/1200
# 41/41 [==============================] - 0s 331us/sample - loss: 0.0242
# Epoch 327/1200
# 41/41 [==============================] - 0s 364us/sample - loss: 0.0241
# Epoch 328/1200
# 41/41 [==============================] - 0s 364us/sample - loss: 0.0241
# Epoch 329/1200
# 41/41 [==============================] - 0s 375us/sample - loss: 0.0241
# Epoch 330/1200
# 41/41 [==============================] - 0s 380us/sample - loss: 0.0240
# Epoch 331/1200
# 41/41 [==============================] - 0s 329us/sample - loss: 0.0240
# Epoch 332/1200
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0240
# Epoch 333/1200
# 41/41 [==============================] - 0s 244us/sample - loss: 0.0239
# Epoch 334/1200
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0239
# Epoch 335/1200
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0239
# Epoch 336/1200
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0239
# Epoch 337/1200
# 41/41 [==============================] - 0s 252us/sample - loss: 0.0238
# Epoch 338/1200
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0238
# Epoch 339/1200
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0238
# Epoch 340/1200
# 41/41 [==============================] - 0s 342us/sample - loss: 0.0237
# Epoch 341/1200
# 41/41 [==============================] - 0s 257us/sample - loss: 0.0237
# Epoch 342/1200
# 41/41 [==============================] - 0s 370us/sample - loss: 0.0237
# Epoch 343/1200
# 41/41 [==============================] - 0s 263us/sample - loss: 0.0237
# Epoch 344/1200
# 41/41 [==============================] - 0s 331us/sample - loss: 0.0236
# Epoch 345/1200
# 41/41 [==============================] - 0s 213us/sample - loss: 0.0236
# Epoch 346/1200
# 41/41 [==============================] - 0s 401us/sample - loss: 0.0236
# Epoch 347/1200
# 41/41 [==============================] - 0s 216us/sample - loss: 0.0235
# Epoch 348/1200
# 41/41 [==============================] - 0s 226us/sample - loss: 0.0235
# Epoch 349/1200
# 41/41 [==============================] - 0s 225us/sample - loss: 0.0235
# Epoch 350/1200
# 41/41 [==============================] - 0s 267us/sample - loss: 0.0235
# Epoch 351/1200
# 41/41 [==============================] - 0s 308us/sample - loss: 0.0234
# Epoch 352/1200
# 41/41 [==============================] - 0s 301us/sample - loss: 0.0234
# Epoch 353/1200
# 41/41 [==============================] - 0s 317us/sample - loss: 0.0234
# Epoch 354/1200
# 41/41 [==============================] - 0s 297us/sample - loss: 0.0234
# Epoch 355/1200
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0234
# Epoch 356/1200
# 41/41 [==============================] - 0s 293us/sample - loss: 0.0233
# Epoch 357/1200
# 41/41 [==============================] - 0s 288us/sample - loss: 0.0233
# Epoch 358/1200
# 41/41 [==============================] - 0s 305us/sample - loss: 0.0232
# Epoch 359/1200
# 41/41 [==============================] - 0s 302us/sample - loss: 0.0232
# Epoch 360/1200
# 41/41 [==============================] - 0s 308us/sample - loss: 0.0232
# Epoch 361/1200
# 41/41 [==============================] - 0s 284us/sample - loss: 0.0232
# Epoch 362/1200
# 41/41 [==============================] - 0s 308us/sample - loss: 0.0231
# Epoch 363/1200
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0231
# Epoch 364/1200
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0231
# Epoch 365/1200
# 41/41 [==============================] - 0s 305us/sample - loss: 0.0230
# Epoch 366/1200
# 41/41 [==============================] - 0s 297us/sample - loss: 0.0230
# Epoch 367/1200
# 41/41 [==============================] - 0s 285us/sample - loss: 0.0230
# Epoch 368/1200
# 41/41 [==============================] - 0s 304us/sample - loss: 0.0229
# Epoch 369/1200
# 41/41 [==============================] - 0s 266us/sample - loss: 0.0229
# Epoch 370/1200
# 41/41 [==============================] - 0s 295us/sample - loss: 0.0229
# Epoch 371/1200
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0229
# Epoch 372/1200
# 41/41 [==============================] - 0s 329us/sample - loss: 0.0228
# Epoch 373/1200
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0228
# Epoch 374/1200
# 41/41 [==============================] - 0s 503us/sample - loss: 0.0228
# Epoch 375/1200
# 41/41 [==============================] - 0s 300us/sample - loss: 0.0228
# Epoch 376/1200
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0227
# Epoch 377/1200
# 41/41 [==============================] - 0s 359us/sample - loss: 0.0227
# Epoch 378/1200
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0227
# Epoch 379/1200
# 41/41 [==============================] - 0s 263us/sample - loss: 0.0227
# Epoch 380/1200
# 41/41 [==============================] - 0s 279us/sample - loss: 0.0226
# Epoch 381/1200
# 41/41 [==============================] - 0s 302us/sample - loss: 0.0226
# Epoch 382/1200
# 41/41 [==============================] - 0s 278us/sample - loss: 0.0226
# Epoch 383/1200
# 41/41 [==============================] - 0s 331us/sample - loss: 0.0225
# Epoch 384/1200
# 41/41 [==============================] - 0s 297us/sample - loss: 0.0225
# Epoch 385/1200
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0225
# Epoch 386/1200
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0225
# Epoch 387/1200
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0224
# Epoch 388/1200
# 41/41 [==============================] - 0s 310us/sample - loss: 0.0224
# Epoch 389/1200
# 41/41 [==============================] - 0s 430us/sample - loss: 0.0224
# Epoch 390/1200
# 41/41 [==============================] - 0s 346us/sample - loss: 0.0223
# Epoch 391/1200
# 41/41 [==============================] - 0s 318us/sample - loss: 0.0223
# Epoch 392/1200
# 41/41 [==============================] - 0s 337us/sample - loss: 0.0223
# Epoch 393/1200
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0223
# Epoch 394/1200
# 41/41 [==============================] - 0s 364us/sample - loss: 0.0222
# Epoch 395/1200
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0222
# Epoch 396/1200
# 41/41 [==============================] - 0s 305us/sample - loss: 0.0222
# Epoch 397/1200
# 41/41 [==============================] - 0s 377us/sample - loss: 0.0222
# Epoch 398/1200
# 41/41 [==============================] - 0s 358us/sample - loss: 0.0221
# Epoch 399/1200
# 41/41 [==============================] - 0s 339us/sample - loss: 0.0221
# Epoch 400/1200
# 41/41 [==============================] - 0s 321us/sample - loss: 0.0221
# Epoch 401/1200
# 41/41 [==============================] - 0s 318us/sample - loss: 0.0221
# Epoch 402/1200
# 41/41 [==============================] - 0s 267us/sample - loss: 0.0220
# Epoch 403/1200
# 41/41 [==============================] - 0s 355us/sample - loss: 0.0220
# Epoch 404/1200
# 41/41 [==============================] - 0s 359us/sample - loss: 0.0220
# Epoch 405/1200
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0220
# Epoch 406/1200
# 41/41 [==============================] - 0s 326us/sample - loss: 0.0219
# Epoch 407/1200
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0219
# Epoch 408/1200
# 41/41 [==============================] - 0s 297us/sample - loss: 0.0219
# Epoch 409/1200
# 41/41 [==============================] - 0s 434us/sample - loss: 0.0219
# Epoch 410/1200
# 41/41 [==============================] - 0s 346us/sample - loss: 0.0218
# Epoch 411/1200
# 41/41 [==============================] - 0s 331us/sample - loss: 0.0218
# Epoch 412/1200
# 41/41 [==============================] - 0s 338us/sample - loss: 0.0218
# Epoch 413/1200
# 41/41 [==============================] - 0s 388us/sample - loss: 0.0217
# Epoch 414/1200
# 41/41 [==============================] - 0s 266us/sample - loss: 0.0217
# Epoch 415/1200
# 41/41 [==============================] - 0s 243us/sample - loss: 0.0217
# Epoch 416/1200
# 41/41 [==============================] - 0s 224us/sample - loss: 0.0217
# Epoch 417/1200
# 41/41 [==============================] - 0s 225us/sample - loss: 0.0216
# Epoch 418/1200
# 41/41 [==============================] - 0s 217us/sample - loss: 0.0216
# Epoch 419/1200
# 41/41 [==============================] - 0s 242us/sample - loss: 0.0216
# Epoch 420/1200
# 41/41 [==============================] - 0s 219us/sample - loss: 0.0216
# Epoch 421/1200
# 41/41 [==============================] - 0s 243us/sample - loss: 0.0215
# Epoch 422/1200
# 41/41 [==============================] - 0s 251us/sample - loss: 0.0215
# Epoch 423/1200
# 41/41 [==============================] - 0s 220us/sample - loss: 0.0215
# Epoch 424/1200
# 41/41 [==============================] - 0s 252us/sample - loss: 0.0215
# Epoch 425/1200
# 41/41 [==============================] - 0s 256us/sample - loss: 0.0215
# Epoch 426/1200
# 41/41 [==============================] - 0s 268us/sample - loss: 0.0214
# Epoch 427/1200
# 41/41 [==============================] - 0s 236us/sample - loss: 0.0214
# Epoch 428/1200
# 41/41 [==============================] - 0s 225us/sample - loss: 0.0214
# Epoch 429/1200
# 41/41 [==============================] - 0s 240us/sample - loss: 0.0214
# Epoch 430/1200
# 41/41 [==============================] - 0s 234us/sample - loss: 0.0213
# Epoch 431/1200
# 41/41 [==============================] - 0s 391us/sample - loss: 0.0213
# Epoch 432/1200
# 41/41 [==============================] - 0s 338us/sample - loss: 0.0213
# Epoch 433/1200
# 41/41 [==============================] - 0s 380us/sample - loss: 0.0213
# Epoch 434/1200
# 41/41 [==============================] - 0s 342us/sample - loss: 0.0213
# Epoch 435/1200
# 41/41 [==============================] - 0s 317us/sample - loss: 0.0213
# Epoch 436/1200
# 41/41 [==============================] - 0s 346us/sample - loss: 0.0212
# Epoch 437/1200
# 41/41 [==============================] - 0s 317us/sample - loss: 0.0212
# Epoch 438/1200
# 41/41 [==============================] - 0s 287us/sample - loss: 0.0212
# Epoch 439/1200
# 41/41 [==============================] - 0s 243us/sample - loss: 0.0212
# Epoch 440/1200
# 41/41 [==============================] - 0s 234us/sample - loss: 0.0211
# Epoch 441/1200
# 41/41 [==============================] - 0s 226us/sample - loss: 0.0211
# Epoch 442/1200
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0211
# Epoch 443/1200
# 41/41 [==============================] - 0s 331us/sample - loss: 0.0211
# Epoch 444/1200
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0210
# Epoch 445/1200
# 41/41 [==============================] - 0s 327us/sample - loss: 0.0210
# Epoch 446/1200
# 41/41 [==============================] - 0s 323us/sample - loss: 0.0210
# Epoch 447/1200
# 41/41 [==============================] - 0s 310us/sample - loss: 0.0210
# Epoch 448/1200
# 41/41 [==============================] - 0s 321us/sample - loss: 0.0210
# Epoch 449/1200
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0209
# Epoch 450/1200
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0209
# Epoch 451/1200
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0209
# Epoch 452/1200
# 41/41 [==============================] - 0s 302us/sample - loss: 0.0209
# Epoch 453/1200
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0209
# Epoch 454/1200
# 41/41 [==============================] - 0s 219us/sample - loss: 0.0208
# Epoch 455/1200
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0208
# Epoch 456/1200
# 41/41 [==============================] - 0s 245us/sample - loss: 0.0208
# Epoch 457/1200
# 41/41 [==============================] - 0s 232us/sample - loss: 0.0208
# Epoch 458/1200
# 41/41 [==============================] - 0s 232us/sample - loss: 0.0207
# Epoch 459/1200
# 41/41 [==============================] - 0s 418us/sample - loss: 0.0207
# Epoch 460/1200
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0207
# Epoch 461/1200
# 41/41 [==============================] - 0s 318us/sample - loss: 0.0207
# Epoch 462/1200
# 41/41 [==============================] - 0s 326us/sample - loss: 0.0207
# Epoch 463/1200
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0206
# Epoch 464/1200
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0206
# Epoch 465/1200
# 41/41 [==============================] - 0s 297us/sample - loss: 0.0206
# Epoch 466/1200
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0206
# Epoch 467/1200
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0205
# Epoch 468/1200
# 41/41 [==============================] - 0s 335us/sample - loss: 0.0205
# Epoch 469/1200
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0205
# Epoch 470/1200
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0205
# Epoch 471/1200
# 41/41 [==============================] - 0s 289us/sample - loss: 0.0204
# Epoch 472/1200
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0204
# Epoch 473/1200
# 41/41 [==============================] - 0s 351us/sample - loss: 0.0204
# Epoch 474/1200
# 41/41 [==============================] - 0s 351us/sample - loss: 0.0204
# Epoch 475/1200
# 41/41 [==============================] - 0s 223us/sample - loss: 0.0204
# Epoch 476/1200
# 41/41 [==============================] - 0s 283us/sample - loss: 0.0204
# Epoch 477/1200
# 41/41 [==============================] - 0s 482us/sample - loss: 0.0203
# Epoch 478/1200
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0203
# Epoch 479/1200
# 41/41 [==============================] - 0s 389us/sample - loss: 0.0203
# Epoch 480/1200
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0203
# Epoch 481/1200
# 41/41 [==============================] - 0s 298us/sample - loss: 0.0203
# Epoch 482/1200
# 41/41 [==============================] - 0s 398us/sample - loss: 0.0202
# Epoch 483/1200
# 41/41 [==============================] - 0s 321us/sample - loss: 0.0202
# Epoch 484/1200
# 41/41 [==============================] - 0s 304us/sample - loss: 0.0202
# Epoch 485/1200
# 41/41 [==============================] - 0s 336us/sample - loss: 0.0202
# Epoch 486/1200
# 41/41 [==============================] - 0s 260us/sample - loss: 0.0201
# Epoch 487/1200
# 41/41 [==============================] - 0s 318us/sample - loss: 0.0201
# Epoch 488/1200
# 41/41 [==============================] - 0s 343us/sample - loss: 0.0201
# Epoch 489/1200
# 41/41 [==============================] - 0s 268us/sample - loss: 0.0201
# Epoch 490/1200
# 41/41 [==============================] - 0s 378us/sample - loss: 0.0201
# Epoch 491/1200
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0200
# Epoch 492/1200
# 41/41 [==============================] - 0s 327us/sample - loss: 0.0200
# Epoch 493/1200
# 41/41 [==============================] - 0s 253us/sample - loss: 0.0200
# Epoch 494/1200
# 41/41 [==============================] - 0s 257us/sample - loss: 0.0200
# Epoch 495/1200
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0200
# Epoch 496/1200
# 41/41 [==============================] - 0s 264us/sample - loss: 0.0199
# Epoch 497/1200
# 41/41 [==============================] - 0s 232us/sample - loss: 0.0199
# Epoch 498/1200
# 41/41 [==============================] - 0s 265us/sample - loss: 0.0199
# Epoch 499/1200
# 41/41 [==============================] - 0s 268us/sample - loss: 0.0199
# Epoch 500/1200
# 41/41 [==============================] - 0s 237us/sample - loss: 0.0198
# Epoch 501/1200
# 41/41 [==============================] - 0s 260us/sample - loss: 0.0198
# Epoch 502/1200
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0198
# Epoch 503/1200
# 41/41 [==============================] - 0s 244us/sample - loss: 0.0198
# Epoch 504/1200
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0198
# Epoch 505/1200
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0198
# Epoch 506/1200
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0198
# Epoch 507/1200
# 41/41 [==============================] - 0s 252us/sample - loss: 0.0198
# Epoch 508/1200
# 41/41 [==============================] - 0s 257us/sample - loss: 0.0197
# Epoch 509/1200
# 41/41 [==============================] - 0s 306us/sample - loss: 0.0197
# Epoch 510/1200
# 41/41 [==============================] - 0s 234us/sample - loss: 0.0197
# Epoch 511/1200
# 41/41 [==============================] - 0s 267us/sample - loss: 0.0197
# Epoch 512/1200
# 41/41 [==============================] - 0s 227us/sample - loss: 0.0197
# Epoch 513/1200
# 41/41 [==============================] - 0s 267us/sample - loss: 0.0197
# Epoch 514/1200
# 41/41 [==============================] - 0s 382us/sample - loss: 0.0197
# Epoch 515/1200
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0196
# Epoch 516/1200
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0196
# Epoch 517/1200
# 41/41 [==============================] - 0s 322us/sample - loss: 0.0196
# Epoch 518/1200
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0196
# Epoch 519/1200
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0195
# Epoch 520/1200
# 41/41 [==============================] - 0s 265us/sample - loss: 0.0195
# Epoch 521/1200
# 41/41 [==============================] - 0s 260us/sample - loss: 0.0195
# Epoch 522/1200
# 41/41 [==============================] - 0s 232us/sample - loss: 0.0195
# Epoch 523/1200
# 41/41 [==============================] - 0s 248us/sample - loss: 0.0195
# Epoch 524/1200
# 41/41 [==============================] - 0s 247us/sample - loss: 0.0195
# Epoch 525/1200
# 41/41 [==============================] - 0s 258us/sample - loss: 0.0194
# Epoch 526/1200
# 41/41 [==============================] - 0s 249us/sample - loss: 0.0194
# Epoch 527/1200
# 41/41 [==============================] - 0s 229us/sample - loss: 0.0194
# Epoch 528/1200
# 41/41 [==============================] - 0s 226us/sample - loss: 0.0194
# Epoch 529/1200
# 41/41 [==============================] - 0s 387us/sample - loss: 0.0194
# Epoch 530/1200
# 41/41 [==============================] - 0s 374us/sample - loss: 0.0194
# Epoch 531/1200
# 41/41 [==============================] - 0s 229us/sample - loss: 0.0194
# Epoch 532/1200
# 41/41 [==============================] - 0s 255us/sample - loss: 0.0193
# Epoch 533/1200
# 41/41 [==============================] - 0s 496us/sample - loss: 0.0193
# Epoch 534/1200
# 41/41 [==============================] - 0s 258us/sample - loss: 0.0193
# Epoch 535/1200
# 41/41 [==============================] - 0s 284us/sample - loss: 0.0193
# Epoch 536/1200
# 41/41 [==============================] - 0s 270us/sample - loss: 0.0193
# Epoch 537/1200
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0192
# Epoch 538/1200
# 41/41 [==============================] - 0s 262us/sample - loss: 0.0192
# Epoch 539/1200
# 41/41 [==============================] - 0s 306us/sample - loss: 0.0192
# Epoch 540/1200
# 41/41 [==============================] - 0s 285us/sample - loss: 0.0192
# Epoch 541/1200
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0192
# Epoch 542/1200
# 41/41 [==============================] - 0s 353us/sample - loss: 0.0192
# Epoch 543/1200
# 41/41 [==============================] - 0s 359us/sample - loss: 0.0192
# Epoch 544/1200
# 41/41 [==============================] - 0s 347us/sample - loss: 0.0191
# Epoch 545/1200
# 41/41 [==============================] - 0s 360us/sample - loss: 0.0191
# Epoch 546/1200
# 41/41 [==============================] - 0s 245us/sample - loss: 0.0191
# Epoch 547/1200
# 41/41 [==============================] - 0s 249us/sample - loss: 0.0191
# Epoch 548/1200
# 41/41 [==============================] - 0s 293us/sample - loss: 0.0190
# Epoch 549/1200
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0190
# Epoch 550/1200
# 41/41 [==============================] - 0s 297us/sample - loss: 0.0190
# Epoch 551/1200
# 41/41 [==============================] - 0s 367us/sample - loss: 0.0190
# Epoch 552/1200
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0190
# Epoch 553/1200
# ...
# 41/41 [==============================] - 0s 311us/sample - loss: 0.0147
# Epoch 1020/1200
# 41/41 [==============================] - 0s 277us/sample - loss: 0.0147
# Epoch 1021/1200
# 41/41 [==============================] - 0s 277us/sample - loss: 0.0147
# Epoch 1022/1200
# 41/41 [==============================] - 0s 257us/sample - loss: 0.0147
# Epoch 1023/1200
# 41/41 [==============================] - 0s 243us/sample - loss: 0.0147
# Epoch 1024/1200
# 41/41 [==============================] - 0s 254us/sample - loss: 0.0147
# Epoch 1025/1200
# 41/41 [==============================] - 0s 264us/sample - loss: 0.0147
# Epoch 1026/1200
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0147
# Epoch 1027/1200
# 41/41 [==============================] - 0s 367us/sample - loss: 0.0146
# Epoch 1028/1200
# 41/41 [==============================] - 0s 400us/sample - loss: 0.0146
# Epoch 1029/1200
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0146
# Epoch 1030/1200
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0146
# Epoch 1031/1200
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0146
# Epoch 1032/1200
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0146
# Epoch 1033/1200
# 41/41 [==============================] - 0s 343us/sample - loss: 0.0146
# Epoch 1034/1200
# 41/41 [==============================] - 0s 323us/sample - loss: 0.0146
# Epoch 1035/1200
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0146
# Epoch 1036/1200
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0146
# Epoch 1037/1200
# 41/41 [==============================] - 0s 344us/sample - loss: 0.0146
# Epoch 1038/1200
# 41/41 [==============================] - 0s 398us/sample - loss: 0.0146
# Epoch 1039/1200
# 41/41 [==============================] - 0s 363us/sample - loss: 0.0146
# Epoch 1040/1200
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0146
# Epoch 1041/1200
# 41/41 [==============================] - 0s 293us/sample - loss: 0.0146
# Epoch 1042/1200
# 41/41 [==============================] - 0s 266us/sample - loss: 0.0146
# Epoch 1043/1200
# 41/41 [==============================] - 0s 333us/sample - loss: 0.0146
# Epoch 1044/1200
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0146
# Epoch 1045/1200
# 41/41 [==============================] - 0s 309us/sample - loss: 0.0146
# Epoch 1046/1200
# 41/41 [==============================] - 0s 310us/sample - loss: 0.0146
# Epoch 1047/1200
# 41/41 [==============================] - 0s 272us/sample - loss: 0.0146
# Epoch 1048/1200
# 41/41 [==============================] - 0s 510us/sample - loss: 0.0145
# Epoch 1049/1200
# 41/41 [==============================] - 0s 337us/sample - loss: 0.0145
# Epoch 1050/1200
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0145
# Epoch 1051/1200
# 41/41 [==============================] - 0s 221us/sample - loss: 0.0145
# Epoch 1052/1200
# 41/41 [==============================] - 0s 222us/sample - loss: 0.0145
# Epoch 1053/1200
# 41/41 [==============================] - 0s 247us/sample - loss: 0.0145
# Epoch 1054/1200
# 41/41 [==============================] - 0s 323us/sample - loss: 0.0145
# Epoch 1055/1200
# 41/41 [==============================] - 0s 339us/sample - loss: 0.0145
# Epoch 1056/1200
# 41/41 [==============================] - 0s 326us/sample - loss: 0.0145
# Epoch 1057/1200
# 41/41 [==============================] - 0s 231us/sample - loss: 0.0145
# Epoch 1058/1200
# 41/41 [==============================] - 0s 275us/sample - loss: 0.0145
# Epoch 1059/1200
# 41/41 [==============================] - 0s 299us/sample - loss: 0.0145
# Epoch 1060/1200
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0145
# Epoch 1061/1200
# 41/41 [==============================] - 0s 340us/sample - loss: 0.0145
# Epoch 1062/1200
# 41/41 [==============================] - 0s 267us/sample - loss: 0.0145
# Epoch 1063/1200
# 41/41 [==============================] - 0s 244us/sample - loss: 0.0145
# Epoch 1064/1200
# 41/41 [==============================] - 0s 279us/sample - loss: 0.0145
# Epoch 1065/1200
# 41/41 [==============================] - 0s 309us/sample - loss: 0.0145
# Epoch 1066/1200
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0145
# Epoch 1067/1200
# 41/41 [==============================] - 0s 321us/sample - loss: 0.0145
# Epoch 1068/1200
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0145
# Epoch 1069/1200
# 41/41 [==============================] - 0s 230us/sample - loss: 0.0145
# Epoch 1070/1200
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0144
# Epoch 1071/1200
# 41/41 [==============================] - 0s 294us/sample - loss: 0.0144
# Epoch 1072/1200
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0144
# Epoch 1073/1200
# 41/41 [==============================] - 0s 268us/sample - loss: 0.0144
# Epoch 1074/1200
# 41/41 [==============================] - 0s 300us/sample - loss: 0.0144
# Epoch 1075/1200
# 41/41 [==============================] - 0s 326us/sample - loss: 0.0144
# Epoch 1076/1200
# 41/41 [==============================] - 0s 274us/sample - loss: 0.0144
# Epoch 1077/1200
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0144
# Epoch 1078/1200
# 41/41 [==============================] - 0s 265us/sample - loss: 0.0144
# Epoch 1079/1200
# 41/41 [==============================] - 0s 246us/sample - loss: 0.0144
# Epoch 1080/1200
# 41/41 [==============================] - 0s 252us/sample - loss: 0.0144
# Epoch 1081/1200
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0144
# Epoch 1082/1200
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0144
# Epoch 1083/1200
# 41/41 [==============================] - 0s 274us/sample - loss: 0.0144
# Epoch 1084/1200
# 41/41 [==============================] - 0s 271us/sample - loss: 0.0144
# Epoch 1085/1200
# 41/41 [==============================] - 0s 280us/sample - loss: 0.0144
# Epoch 1086/1200
# 41/41 [==============================] - 0s 292us/sample - loss: 0.0144
# Epoch 1087/1200
# 41/41 [==============================] - 0s 282us/sample - loss: 0.0144
# Epoch 1088/1200
# 41/41 [==============================] - 0s 256us/sample - loss: 0.0144
# Epoch 1089/1200
# 41/41 [==============================] - 0s 278us/sample - loss: 0.0144
# Epoch 1090/1200
# 41/41 [==============================] - 0s 315us/sample - loss: 0.0144
# Epoch 1091/1200
# 41/41 [==============================] - 0s 301us/sample - loss: 0.0144
# Epoch 1092/1200
# 41/41 [==============================] - 0s 322us/sample - loss: 0.0143
# Epoch 1093/1200
# 41/41 [==============================] - 0s 343us/sample - loss: 0.0143
# Epoch 1094/1200
# 41/41 [==============================] - 0s 385us/sample - loss: 0.0144
# Epoch 1095/1200
# 41/41 [==============================] - 0s 315us/sample - loss: 0.0143
# Epoch 1096/1200
# 41/41 [==============================] - 0s 344us/sample - loss: 0.0143
# Epoch 1097/1200
# 41/41 [==============================] - 0s 284us/sample - loss: 0.0143
# Epoch 1098/1200
# 41/41 [==============================] - 0s 373us/sample - loss: 0.0143
# Epoch 1099/1200
# 41/41 [==============================] - 0s 316us/sample - loss: 0.0143
# Epoch 1100/1200
# 41/41 [==============================] - 0s 304us/sample - loss: 0.0143
# Epoch 1101/1200
# 41/41 [==============================] - 0s 366us/sample - loss: 0.0143
# Epoch 1102/1200
# 41/41 [==============================] - 0s 315us/sample - loss: 0.0143
# Epoch 1103/1200
# 41/41 [==============================] - 0s 305us/sample - loss: 0.0143
# Epoch 1104/1200
# 41/41 [==============================] - 0s 250us/sample - loss: 0.0143
# Epoch 1105/1200
# 41/41 [==============================] - 0s 277us/sample - loss: 0.0143
# Epoch 1106/1200
# 41/41 [==============================] - 0s 222us/sample - loss: 0.0143
# Epoch 1107/1200
# 41/41 [==============================] - 0s 452us/sample - loss: 0.0143
# Epoch 1108/1200
# 41/41 [==============================] - 0s 386us/sample - loss: 0.0143
# Epoch 1109/1200
# 41/41 [==============================] - 0s 377us/sample - loss: 0.0143
# Epoch 1110/1200
# 41/41 [==============================] - 0s 285us/sample - loss: 0.0143
# Epoch 1111/1200
# 41/41 [==============================] - 0s 409us/sample - loss: 0.0143
# Epoch 1112/1200
# 41/41 [==============================] - 0s 400us/sample - loss: 0.0143
# Epoch 1113/1200
# 41/41 [==============================] - 0s 329us/sample - loss: 0.0143
# Epoch 1114/1200
# 41/41 [==============================] - 0s 287us/sample - loss: 0.0143
# Epoch 1115/1200
# 41/41 [==============================] - 0s 352us/sample - loss: 0.0143
# Epoch 1116/1200
# 41/41 [==============================] - 0s 443us/sample - loss: 0.0143
# Epoch 1117/1200
# 41/41 [==============================] - 0s 453us/sample - loss: 0.0143
# Epoch 1118/1200
# 41/41 [==============================] - 0s 369us/sample - loss: 0.0143
# Epoch 1119/1200
# 41/41 [==============================] - 0s 300us/sample - loss: 0.0143
# Epoch 1120/1200
# 41/41 [==============================] - 0s 322us/sample - loss: 0.0143
# Epoch 1121/1200
# 41/41 [==============================] - 0s 307us/sample - loss: 0.0143
# Epoch 1122/1200
# 41/41 [==============================] - 0s 356us/sample - loss: 0.0143
# Epoch 1123/1200
# 41/41 [==============================] - 0s 336us/sample - loss: 0.0142
# Epoch 1124/1200
# 41/41 [==============================] - 0s 308us/sample - loss: 0.0142
# Epoch 1125/1200
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0142
# Epoch 1126/1200
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0142
# Epoch 1127/1200
# 41/41 [==============================] - 0s 322us/sample - loss: 0.0142
# Epoch 1128/1200
# 41/41 [==============================] - 0s 352us/sample - loss: 0.0142
# Epoch 1129/1200
# 41/41 [==============================] - 0s 269us/sample - loss: 0.0142
# Epoch 1130/1200
# 41/41 [==============================] - 0s 286us/sample - loss: 0.0142
# Epoch 1131/1200
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0142
# Epoch 1132/1200
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0142
# Epoch 1133/1200
# 41/41 [==============================] - 0s 299us/sample - loss: 0.0142
# Epoch 1134/1200
# 41/41 [==============================] - 0s 324us/sample - loss: 0.0142
# Epoch 1135/1200
# 41/41 [==============================] - 0s 299us/sample - loss: 0.0142
# Epoch 1136/1200
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0142
# Epoch 1137/1200
# 41/41 [==============================] - 0s 266us/sample - loss: 0.0142
# Epoch 1138/1200
# 41/41 [==============================] - 0s 318us/sample - loss: 0.0142
# Epoch 1139/1200
# 41/41 [==============================] - 0s 225us/sample - loss: 0.0142
# Epoch 1140/1200
# 41/41 [==============================] - 0s 291us/sample - loss: 0.0142
# Epoch 1141/1200
# 41/41 [==============================] - 0s 260us/sample - loss: 0.0142
# Epoch 1142/1200
# 41/41 [==============================] - 0s 251us/sample - loss: 0.0142
# Epoch 1143/1200
# 41/41 [==============================] - 0s 340us/sample - loss: 0.0142
# Epoch 1144/1200
# 41/41 [==============================] - 0s 301us/sample - loss: 0.0142
# Epoch 1145/1200
# 41/41 [==============================] - 0s 320us/sample - loss: 0.0142
# Epoch 1146/1200
# 41/41 [==============================] - 0s 312us/sample - loss: 0.0142
# Epoch 1147/1200
# 41/41 [==============================] - 0s 326us/sample - loss: 0.0142
# Epoch 1148/1200
# 41/41 [==============================] - 0s 321us/sample - loss: 0.0142
# Epoch 1149/1200
# 41/41 [==============================] - 0s 332us/sample - loss: 0.0142
# Epoch 1150/1200
# 41/41 [==============================] - 0s 313us/sample - loss: 0.0142
# Epoch 1151/1200
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0142
# Epoch 1152/1200
# 41/41 [==============================] - 0s 349us/sample - loss: 0.0142
# Epoch 1153/1200
# 41/41 [==============================] - 0s 318us/sample - loss: 0.0142
# Epoch 1154/1200
# 41/41 [==============================] - 0s 332us/sample - loss: 0.0142
# Epoch 1155/1200
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0142
# Epoch 1156/1200
# 41/41 [==============================] - 0s 311us/sample - loss: 0.0141
# Epoch 1157/1200
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0142
# Epoch 1158/1200
# 41/41 [==============================] - 0s 319us/sample - loss: 0.0142
# Epoch 1159/1200
# 41/41 [==============================] - 0s 306us/sample - loss: 0.0141
# Epoch 1160/1200
# 41/41 [==============================] - 0s 350us/sample - loss: 0.0141
# Epoch 1161/1200
# 41/41 [==============================] - 0s 351us/sample - loss: 0.0141
# Epoch 1162/1200
# 41/41 [==============================] - 0s 349us/sample - loss: 0.0141
# Epoch 1163/1200
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0141
# Epoch 1164/1200
# 41/41 [==============================] - 0s 314us/sample - loss: 0.0141
# Epoch 1165/1200
# 41/41 [==============================] - 0s 298us/sample - loss: 0.0141
# Epoch 1166/1200
# 41/41 [==============================] - 0s 296us/sample - loss: 0.0141
# Epoch 1167/1200
# 41/41 [==============================] - 0s 338us/sample - loss: 0.0141
# Epoch 1168/1200
# 41/41 [==============================] - 0s 332us/sample - loss: 0.0141
# Epoch 1169/1200
# 41/41 [==============================] - 0s 375us/sample - loss: 0.0141
# Epoch 1170/1200
# 41/41 [==============================] - 0s 336us/sample - loss: 0.0141
# Epoch 1171/1200
# 41/41 [==============================] - 0s 310us/sample - loss: 0.0141
# Epoch 1172/1200
# 41/41 [==============================] - 0s 276us/sample - loss: 0.0141
# Epoch 1173/1200
# 41/41 [==============================] - 0s 337us/sample - loss: 0.0141
# Epoch 1174/1200
# 41/41 [==============================] - 0s 415us/sample - loss: 0.0141
# Epoch 1175/1200
# 41/41 [==============================] - 0s 395us/sample - loss: 0.0141
# Epoch 1176/1200
# 41/41 [==============================] - 0s 293us/sample - loss: 0.0141
# Epoch 1177/1200
# 41/41 [==============================] - 0s 308us/sample - loss: 0.0141
# Epoch 1178/1200
# 41/41 [==============================] - 0s 302us/sample - loss: 0.0141
# Epoch 1179/1200
# 41/41 [==============================] - 0s 308us/sample - loss: 0.0141
# Epoch 1180/1200
# 41/41 [==============================] - 0s 340us/sample - loss: 0.0141
# Epoch 1181/1200
# 41/41 [==============================] - 0s 690us/sample - loss: 0.0141
# Epoch 1182/1200
# 41/41 [==============================] - 0s 325us/sample - loss: 0.0141
# Epoch 1183/1200
# 41/41 [==============================] - 0s 303us/sample - loss: 0.0141
# Epoch 1184/1200
# 41/41 [==============================] - 0s 322us/sample - loss: 0.0141
# Epoch 1185/1200
# 41/41 [==============================] - 0s 353us/sample - loss: 0.0140
# Epoch 1186/1200
# 41/41 [==============================] - 0s 343us/sample - loss: 0.0140
# Epoch 1187/1200
# 41/41 [==============================] - 0s 376us/sample - loss: 0.0140
# Epoch 1188/1200
# 41/41 [==============================] - 0s 317us/sample - loss: 0.0141
# Epoch 1189/1200
# 41/41 [==============================] - 0s 345us/sample - loss: 0.0140
# Epoch 1190/1200
# 41/41 [==============================] - 0s 369us/sample - loss: 0.0140
# Epoch 1191/1200
# 41/41 [==============================] - 0s 328us/sample - loss: 0.0140
# Epoch 1192/1200
# 41/41 [==============================] - 0s 332us/sample - loss: 0.0140
# Epoch 1193/1200
# 41/41 [==============================] - 0s 299us/sample - loss: 0.0140
# Epoch 1194/1200
# 41/41 [==============================] - 0s 227us/sample - loss: 0.0140
# Epoch 1195/1200
# 41/41 [==============================] - 0s 260us/sample - loss: 0.0140
# Epoch 1196/1200
# 41/41 [==============================] - 0s 375us/sample - loss: 0.0140
# Epoch 1197/1200
# 41/41 [==============================] - 0s 350us/sample - loss: 0.0140
# Epoch 1198/1200
# 41/41 [==============================] - 0s 359us/sample - loss: 0.0140
# Epoch 1199/1200
# 41/41 [==============================] - 0s 345us/sample - loss: 0.0140
# Epoch 1200/1200
# 41/41 [==============================] - 0s 369us/sample - loss: 0.0140

# %% [markdown]
# Plot the loss history values to see if out model converged
#
# Because a model can have a history of many  different metrics over time, there is a history object which has a keys dictionary of
# metrics whose values were stored on each epoch. By plotting the values for the 'loss' key we can answer:
#
#
# 1.   Did the loss converge?
# 2.   How many epochs were required for the loss to converge?

# %%
train_hist.history['loss'].extend(train_hist_addn.history['loss'])   # add the addition epochs to the  training history
plot_loss(train_hist)

# %% [markdown]
# ### Visually Confirm Model after Additional Training
#
# As the  plot showed, the model's loss converged by 1000 epochs.  So the model should be trained to allow us to make accurate predictions.
#
# Let's again plot the predict the price for each siz.  And see if a line drawn with the learned weight and bias looks reasonable.

# %%
# Visualize data and regression line for learned weights
price_predicted_scaled =  model.predict(sf_train_scaled)
visualize_data(sf_scaler.inverse_transform(sf_train_scaled), 
               price_scaler.inverse_transform(price_train_scaled),
               sf_scaler.inverse_transform(sf_train_scaled), 
               price_scaler.inverse_transform(price_predicted_scaled),
               add_addn_reg_line=False)

# %% [markdown]
# **Yes.  The predicted line looks good!!!**

# %% [markdown]
# ## Test Trained Model
#
# Once we have the model trained, we want to the trained **with data not used to train the model!!!**
#
# The use of data not used in training to test the model is key.  If you use training data our testing results will be overly accurate and will not relect *"real-life"* usage of trained model to make predictions.

# %%
# Make a price prediction on data the model has never seen before, i.e. 
#    the Test data square footage
price_test_pred_scaled = model.predict(sf_test_scaled)

# calculate the mean squared error for the prediction, lower is better
from sklearn.metrics import mean_squared_error
print("prediction mean squared error:", 
          mean_squared_error(price_test_scaled, price_test_pred_scaled ))

# Visualize data and regression line 
#    plus the test square footable and predicted price
print('\nGreen triangles are Test actual Square footage and predicted Price')
visualize_data(sf_scaler.inverse_transform(sf_test_scaled),
               price_scaler.inverse_transform(price_test_scaled),
               sf_scaler.inverse_transform(sf_test_scaled), 
               price_scaler.inverse_transform(price_test_pred_scaled),
               add_addn_reg_line=False)
print('\nOur predicted values fit the data well!')
# Out:
# prediction mean squared error: 0.019291316103068525
#
# Green triangles are Test actual Square footage and predicted Price
# Our predicted values fit the data well!

# %% [markdown]
# ## What we have learned
#
#
#
# *   In Machine Learning we oftens spend considerable effort getting data in a form were our models can learn from the data.
# * A single neuron model can learn from data how to learn the appropriate slope and offset for the data
# *   Building this model was made easier by TensorFlow's implementation of the Keras library
# *   But to learn from the data we need to pass the data through the model enough times to get the loss to converge
# *   When we do that, the model learn the data's slope and offset.
# *  And when we apply these learned values, the predict prices from the test data's Square Footage are reasonable.
